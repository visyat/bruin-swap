# %% [markdown]
# Here is the final scraper that we will be using to populate the database.  We will be pdf scraping since there were technical limitations scraping the course website. (likely protections from UCLA)

# %%
#importing necessary packages
import PyPDF2
import re

# %%
#putting the pdf of the UCLA catalog into a string
#takes a while to run, ~1 minute depending on device
def extract_text_from_pdf(pdf_path, start_page=1, end_page=890):
    text = ""
    #opens pdf
    with open(pdf_path, 'rb') as file:
        reader = PyPDF2.PdfReader(file)
        start_page = max(0, start_page - 1)  
        end_page = min(end_page, len(reader.pages))
        #chooses which pages to parse through - the whole pdf in this case
        for page_number in range(start_page, end_page):
            page = reader.pages[page_number]
            text += page.extract_text()
    return text

pdf_text = extract_text_from_pdf('/Users/dayfamily/Desktop/UCLA_Catalog_2023-24.pdf', start_page=1, end_page=890)

# %%
#defining only the sections we need to get course codes and course names, and potentially majors associated, although we run into difficulties as demonstrated later
#also takes a while to run, ~1 minute depending on device.
class_text = extract_text_from_pdf('/Users/dayfamily/Desktop/UCLA_Catalog_2023-24.pdf', start_page=180, end_page=890)

# %% [markdown]
# How we are going to input what we scrape into the database:
#
# INSERT INTO classes VALUES ('course_code', 'dept_code', 'course_num', 'course_name', 'prof', 'discussion_code');
#
# ex:  INSERT INTO classes VALUES ('CS000331A', 'COM SCI', '33', 'Introduction to Computer Organization', 'Reinman, G.D.', '1A');
#
# So, we will need to make an array that has the following elements: course_code, dept_code, course_num, course_name, prof, and discussion_code.  Unfortunately, due to the inability to scrape the registrar, we will have to use dummy variables for prof and discussion_code, as those things will be variate by quarter and not something we can confirm off of the pdf version of the course catalog.

# %%
#a regular expression that looks for a specific pattern that matches how the pdf stores info about course_names and course_codes; not completely perfect, especially when it comes to things like fiat lux or research
course_pattern = r'(\b[A-Za-z]*\d+[A-Za-z]?)\.\s(.+?)\.'
course_matches = re.findall(course_pattern, class_text)

# %%
#commented out below line since it has a huge output, it also takes ~2 minutes to run depending on your device
#BEWARE SOMETIMES CRASHES
#print(course_matches)

# %%
#preliminary array using what info we got so far
courses_array = []
for match in course_matches:
    course_code = match[0]
    course_name = match[1]
    courses_array.append(["", "", course_code, course_name, "", ""])

# %%
#prints every row - but start lower if it is crashing
for row_index, row_data in enumerate(courses_array[:12000], start=1):
    print(f"Row {row_index}: {row_data}")

# %% [markdown]
# There are over 10,000 classes, and there is no easy way to assign a major to each of them... I attempted to use different regular expressions to scrape major names on a given page and then I could subsequently assign the classes on that page to that major, but to no avail with the given formatting.  Thus, the only way to assign majors to each course, would be to do so manually, and I will not be doing all 11,000 courses.  Instead, I can do it "semi-manually", where I look at which range each class is, and assign the dept_code to those courses.  I could also write a program to do that based on perhaps if the next course number is lower than the previous one, and to change the dept_code accordingly, but that is prone to errors and having incorrect information seems worse than having incomplete information.  So, I will input dept_code information "manually" for the time being.  I will do the first couple of majors, and then prioritize popular majors like computer science, mathematics, and political science.

# %%
#complete list of dept_codes, found on https://github.com/nnhien/uclacatalog/wiki
dept_abbr = {
    "AERO ST",
    "AF AMER",
    "AFRC ST",
    "AM IND",
    "ASL",
    "AN N EA",
    "ANES",
    "ANTHRO",
    "APPLING",
    "ARABIC",
    "ARCHEOL",
    "ARCH&UD",
    "ARMENIA",
    "ART",
    "ART HIS",
    "ART&ARC",
    "ARTS ED",
    "ASIAN",
    "ASIA AM",
    "ASTR",
    "A&O SCI",
    "BIOENGR",
    "BIOINFO",
    "BIOINFR",
    "BIOL CH",
    "BIOMATH",
    "BMD RES",
    "BIOSTAT",
    "C&EE ST",
    "CH ENGR",
    "CHEM",
    "CHICANO",
    "CHIN",
    "C&EE",
    "CLASSIC",
    "CLUSTER",
    "COMM",
    "CESC",
    "COM HLT",
    "COM LIT",
    "C&S BIO",
    "COM SCI",
    "CAEM",
    "DANCE",
    "DENT",
    "DESMA",
    "DGT HUM",
    "DIS STD",
    "DUTCH",
    "EPS SCI",
    "EA STDS",
    "EE BIOL",
    "ECON",
    "EDUC",
    "EC ENGR",
    "ENGR",
    "ENGL",
    "ESL",
    "ENGCOMP",
    "ENVIRON",
    "ENV HLT",
    "EPIDEM",
    "ETHNMUS",
    "FILIPNO",
    "FILM TV",
    "FOOD ST",
    "FRNCH",
    "GENDER",
    "GEOG",
    "GERMAN",
    "GRNTLGY",
    "GLB HLT",
    "GJ STDS",
    "GLBL ST",
    "GRAD PD",
    "GREEK",
    "HLT POL",
    "HEBREW",
    "HIN-URD",
    "HIST",
    "HNRS",
    "HUM GEN",
    "HNGAR",
    "IL AMER",
    "I E STD",
    "INDO",
    "INF STD",
    "I A STD",
    "INTL DV",
    "I M STD",
    "IRANIAN",
    "ISLM ST",
    "ITALIAN",
    "JAPAN",
    "JEWISH",
    "KOREA",
    "LBR STD",
    "LATIN",
    "LATN AM",
    "LAW",
    "UG-LAW",
    "LGBTQS",
    "LIFESCI",
    "LING",
    "MGMT",
    "MGMTEX",
    "MGMTFT",
    "MGMTFE",
    "MGMTGEX",
    "MGMTMFE",
    "MGMTMSA",
    "MGMTPHD",
    "MAT SCI",
    "MATH",
    "MECH&AE",
    "MED",
    "MIMG",
    "M E STD",
    "MIL SCI",
    "M PHARM",
    "MOL BIO",
    "MOL TOX",
    "MCD BIO",
    "MC&IP",
    "MUSC",
    "MSC IND",
    "MUSCLG",
    "NAV SCI",
    "NR EAST",
    "NEURBIO",
    "NEURLGY",
    "NEURO",
    "NEUROSC",
    "NEURSGY",
    "NURSING",
    "OBGYN",
    "OPTH",
    "ORL BIO",
    "ORTHPDC",
    "PATH",
    "PEDS",
    "PHILOS",
    "PHYSICS",
    "PBMED",
    "PHYSCI",
    "PHYSIOL",
    "POLSH",
    "POL SCI",
    "PORTGSE",
    "COMPTNG",
    "PSYCTRY",
    "PSYCH",
    "PUB AFF",
    "PUB HLT",
    "PUB PLC",
    "RAD ONC",
    "RELIGN",
    "ROMANIA",
    "RUSSN",
    "SCAND",
    "SCI EDU",
    "SEMITIC",
    "SRB CRO",
    "SLAVC",
    "SOC SC",
    "SOC THT",
    "SOC WLF",
    "SOC GEN",
    "SOCIOL",
    "S ASIAN",
    "SEASIAN",
    "SPAN",
    "STATS",
    "SURGERY",
    "SWAHILI",
    "THAI",
    "THEATER",
    "TURKIC",
    "UNIV ST",
    "URBN PL",
    "UROLOGY",
    "VIETMSE",
    "WL ARTS",
    "YIDDSH"
}

# %% [markdown]
# This is the beginning of "Semi-manually" assigning majors to classes - I will do the first 3 majors, and then the ones I specified above.  I may also fill in the remaining with "dummy major abreviations", aka fill them out with dept_codes even if they are inaccurate so that they populate the database.

# %%
#I will essentially be copying this cell for as many majors as I fill out - replacing the dept_code and range accordingly.  I will be determining the range by looking at the last class listed for each major on the pdf of the general catalog.

#here is the first one: AERO ST

# Given dept_code to assign
dept_code = "AERO ST"

# Assigning the dept_code to the second column of however many classes it corresponds to
for row_index in range(0,5):
    courses_array[row_index][1] = dept_code

# %%
# Printing the updated array
for row in courses_array:
    print(row)

# %%
# Given dept_code to assign
dept_code = "AF AMER"

# Assigning the dept_code to the second column of however many classes it corresponds to
for row_index in range(5,102):
    courses_array[row_index][1] = dept_code

# Printing the updated array
for row in courses_array:
    print(row)

# %%
# Given dept_code to assign
dept_code = "POLI SCI"

# Assigning the dept_code to the second column of however many classes it corresponds to
for row_index in range(8997,9197):
    courses_array[row_index][1] = dept_code

# Printing the updated array
for row in courses_array:
    print(row)

# %%
# Given dept_code to assign
dept_code = "COM SCI"

# Assigning the dept_code to the second column of however many classes it corresponds to
for row_index in range(2793,2853):
    courses_array[row_index][1] = dept_code

# Printing the updated array
for row in courses_array:
    print(row)

# %%
# Given dept_code to assign
dept_code = "MATH"

# Assigning the dept_code to the second column of however many classes it corresponds to
for row_index in range(6975,7207):
    courses_array[row_index][1] = dept_code

# Printing the updated array
for row in courses_array:
    print(row)

# %% [markdown]
# Okay, using the classes that I have filled out a dept_code for, I will now make a new array and fill out dummy discussion sections for them.

# %%
# Create a new array containing only rows with non-empty second elements
discussions_template_array = [row for row in courses_array if row[1] != ""]

# Print the new array
for row in discussions_template_array:
    print(row)

# %%
for row in discussions_template_array:
    row[5] = "1A"

for row in discussions_template_array:
    print(row)

# %%
discussions_updated_array = []

for row in discussions_array:
    # Create a duplicate row with the value of the sixth column changed to "1B"
    duplicate_row_1b = row[:]  # Create a shallow copy of the original row
    duplicate_row_1b[5] = "1B"  # Update the value of the sixth column to "1B"
    duplicate_row_1c = row[:]  # Create a shallow copy of the original row
    duplicate_row_1c[5] = "1C"  # Update the value of the sixth column to "1B"
    duplicate_row_1d = row[:]  # Create a shallow copy of the original row
    duplicate_row_1d[5] = "1D"  # Update the value of the sixth column to "1B"
    
    # Append the original row and the duplicate row to the updated array
    discussions_updated_array.append(row)
    discussions_updated_array.append(duplicate_row_1b)
    discussions_updated_array.append(duplicate_row_1c)
    discussions_updated_array.append(duplicate_row_1d)

for row in discussions_updated_array:
    print(row)

# %% [markdown]
# Now that each class has 4 discussion sections, a dept code, a course code, and a course name, I will assign a dummy variable to be their professor - I will update it with more apt names when adding it to the website.

# %%
for row in discussions_updated_array:
    row[4] = "Eggert, P.R."

for row in discussions_updated_array:
    print(row)

# %% [markdown]
# Now, all I need to have some classes completely filled out and ready to populate the database is to give each class a unique course_code.  This will look like the following:
#
# 2 letters representing the dept_code i.e. CS for COMP SCI
# 5 characters representing the course_num, i.e. 00001 for Introduction to Black Studies
# 2 characters representing the discussion_code i.e. 1C

# %%
for row in discussions_updated_array:
    # Extract relevant information from the row
    dept_code = row[1]
    course_num = row[2]
    discussion_code = row[5]
    
    # Construct the course code
    if dept_code == 'COM SCI':
        course_code = 'CS' + '0' * (5 - len(course_num)) + course_num + discussion_code
    elif dept_code == 'AERO ST':
        course_code = 'AS' + '0' * (5 - len(course_num)) + course_num + discussion_code
    elif dept_code == 'POLI SCI':
        course_code = 'PS' + '0' * (5 - len(course_num)) + course_num + discussion_code
    elif dept_code == 'MATH':
        course_code = 'MT' + '0' * (5 - len(course_num)) + course_num + discussion_code
    elif dept_code == 'AF AMER':
        course_code = 'AA' + '0' * (5 - len(course_num)) + course_num + discussion_code
        pass

    
    # Update the first column of the row with the constructed course code
    row[0] = course_code

# %%
for row in discussions_updated_array:
    print(row)
# Out:
# ['AS0001C1A', 'AERO ST', '1C', 'Heritage and Values', 'Eggert, P.R.', '1A']
# ['AS0001C1B', 'AERO ST', '1C', 'Heritage and Values', 'Eggert, P.R.', '1B']
# ['AS0001C1C', 'AERO ST', '1C', 'Heritage and Values', 'Eggert, P.R.', '1C']
# ['AS0001C1D', 'AERO ST', '1C', 'Heritage and Values', 'Eggert, P.R.', '1D']
# ['AS000191A', 'AERO ST', '19', 'Fiat Lux Freshman Seminars', 'Eggert, P.R.', '1A']
# ['AS000191B', 'AERO ST', '19', 'Fiat Lux Freshman Seminars', 'Eggert, P.R.', '1B']
# ['AS000191C', 'AERO ST', '19', 'Fiat Lux Freshman Seminars', 'Eggert, P.R.', '1C']
# ['AS000191D', 'AERO ST', '19', 'Fiat Lux Freshman Seminars', 'Eggert, P.R.', '1D']
# ['AS0020C1A', 'AERO ST', '20C', 'Team and Leadership Fundamentals', 'Eggert, P.R.', '1A']
# ['AS0020C1B', 'AERO ST', '20C', 'Team and Leadership Fundamentals', 'Eggert, P.R.', '1B']
# ['AS0020C1C', 'AERO ST', '20C', 'Team and Leadership Fundamentals', 'Eggert, P.R.', '1C']
# ['AS0020C1D', 'AERO ST', '20C', 'Team and Leadership Fundamentals', 'Eggert, P.R.', '1D']
# ['AS0130C1A', 'AERO ST', '130C', 'Air Force Leadership Studies', 'Eggert, P.R.', '1A']
# ['AS0130C1B', 'AERO ST', '130C', 'Air Force Leadership Studies', 'Eggert, P.R.', '1B']
# ['AS0130C1C', 'AERO ST', '130C', 'Air Force Leadership Studies', 'Eggert, P.R.', '1C']
# ['AS0130C1D', 'AERO ST', '130C', 'Air Force Leadership Studies', 'Eggert, P.R.', '1D']
# ['AS001971A', 'AERO ST', '197', 'Individual Studies in Aerospace Studies', 'Eggert, P.R.', '1A']
# ['AS001971B', 'AERO ST', '197', 'Individual Studies in Aerospace Studies', 'Eggert, P.R.', '1B']
# ['AS001971C', 'AERO ST', '197', 'Individual Studies in Aerospace Studies', 'Eggert, P.R.', '1C']
# ['AS001971D', 'AERO ST', '197', 'Individual Studies in Aerospace Studies', 'Eggert, P.R.', '1D']
# ['AA000011A', 'AF AMER', '1', 'Introduction to Black Studies', 'Eggert, P.R.', '1A']
# ['AA000011B', 'AF AMER', '1', 'Introduction to Black Studies', 'Eggert, P.R.', '1B']
# ['AA000011C', 'AF AMER', '1', 'Introduction to Black Studies', 'Eggert, P.R.', '1C']
# ['AA000011D', 'AF AMER', '1', 'Introduction to Black Studies', 'Eggert, P.R.', '1D']
# ['AA0002A1A', 'AF AMER', '2A', 'Africa and Middle East', 'Eggert, P.R.', '1A']
# ['AA0002A1B', 'AF AMER', '2A', 'Africa and Middle East', 'Eggert, P.R.', '1B']
# ['AA0002A1C', 'AF AMER', '2A', 'Africa and Middle East', 'Eggert, P.R.', '1C']
# ['AA0002A1D', 'AF AMER', '2A', 'Africa and Middle East', 'Eggert, P.R.', '1D']
# ['AA0002B1A', 'AF AMER', '2B', 'Race and U', 'Eggert, P.R.', '1A']
# ['AA0002B1B', 'AF AMER', '2B', 'Race and U', 'Eggert, P.R.', '1B']
# ['AA0002B1C', 'AF AMER', '2B', 'Race and U', 'Eggert, P.R.', '1C']
# ['AA0002B1D', 'AF AMER', '2B', 'Race and U', 'Eggert, P.R.', '1D']
# ['AA000M51A', 'AF AMER', 'M5', 'Social Organization of Black Communities', 'Eggert, P.R.', '1A']
# ['AA000M51B', 'AF AMER', 'M5', 'Social Organization of Black Communities', 'Eggert, P.R.', '1B']
# ['AA000M51C', 'AF AMER', 'M5', 'Social Organization of Black Communities', 'Eggert, P.R.', '1C']
# ['AA000M51D', 'AF AMER', 'M5', 'Social Organization of Black Communities', 'Eggert, P.R.', '1D']
# ['AA000061A', 'AF AMER', '6', 'Trends in Black Intellectual Thought', 'Eggert, P.R.', '1A']
# ['AA000061B', 'AF AMER', '6', 'Trends in Black Intellectual Thought', 'Eggert, P.R.', '1B']
# ['AA000061C', 'AF AMER', '6', 'Trends in Black Intellectual Thought', 'Eggert, P.R.', '1C']
# ['AA000061D', 'AF AMER', '6', 'Trends in Black Intellectual Thought', 'Eggert, P.R.', '1D']
# ['AA00M7C1A', 'AF AMER', 'M7C', 'Elementary Yoruba', 'Eggert, P.R.', '1A']
# ['AA00M7C1B', 'AF AMER', 'M7C', 'Elementary Yoruba', 'Eggert, P.R.', '1B']
# ['AA00M7C1C', 'AF AMER', 'M7C', 'Elementary Yoruba', 'Eggert, P.R.', '1C']
# ['AA00M7C1D', 'AF AMER', 'M7C', 'Elementary Yoruba', 'Eggert, P.R.', '1D']
# ['AA00M9C1A', 'AF AMER', 'M9C', 'Elementary Amharic', 'Eggert, P.R.', '1A']
# ['AA00M9C1B', 'AF AMER', 'M9C', 'Elementary Amharic', 'Eggert, P.R.', '1B']
# ['AA00M9C1C', 'AF AMER', 'M9C', 'Elementary Amharic', 'Eggert, P.R.', '1C']
# ['AA00M9C1D', 'AF AMER', 'M9C', 'Elementary Amharic', 'Eggert, P.R.', '1D']
# ['AA0M10A1A', 'AF AMER', 'M10A', 'History of Africa to 1800', 'Eggert, P.R.', '1A']
# ['AA0M10A1B', 'AF AMER', 'M10A', 'History of Africa to 1800', 'Eggert, P.R.', '1B']
# ['AA0M10A1C', 'AF AMER', 'M10A', 'History of Africa to 1800', 'Eggert, P.R.', '1C']
# ['AA0M10A1D', 'AF AMER', 'M10A', 'History of Africa to 1800', 'Eggert, P.R.', '1D']
# ['AA00M181A', 'AF AMER', 'M18', 'Leadership and Student-Initiated Retention', 'Eggert, P.R.', '1A']
# ['AA00M181B', 'AF AMER', 'M18', 'Leadership and Student-Initiated Retention', 'Eggert, P.R.', '1B']
# ['AA00M181C', 'AF AMER', 'M18', 'Leadership and Student-Initiated Retention', 'Eggert, P.R.', '1C']
# ['AA00M181D', 'AF AMER', 'M18', 'Leadership and Student-Initiated Retention', 'Eggert, P.R.', '1D']
# ['AA000191A', 'AF AMER', '19', 'Fiat Lux Freshman Seminars', 'Eggert, P.R.', '1A']
# ['AA000191B', 'AF AMER', '19', 'Fiat Lux Freshman Seminars', 'Eggert, P.R.', '1B']
# ['AA000191C', 'AF AMER', '19', 'Fiat Lux Freshman Seminars', 'Eggert, P.R.', '1C']
# ['AA000191D', 'AF AMER', '19', 'Fiat Lux Freshman Seminars', 'Eggert, P.R.', '1D']
# ['AA000891A', 'AF AMER', '89', 'Honors Seminars', 'Eggert, P.R.', '1A']
# ['AA000891B', 'AF AMER', '89', 'Honors Seminars', 'Eggert, P.R.', '1B']
# ['AA000891C', 'AF AMER', '89', 'Honors Seminars', 'Eggert, P.R.', '1C']
# ['AA000891D', 'AF AMER', '89', 'Honors Seminars', 'Eggert, P.R.', '1D']
# ['AA000991A', 'AF AMER', '99', 'Student Research Program', 'Eggert, P.R.', '1A']
# ['AA000991B', 'AF AMER', '99', 'Student Research Program', 'Eggert, P.R.', '1B']
# ['AA000991C', 'AF AMER', '99', 'Student Research Program', 'Eggert, P.R.', '1C']
# ['AA000991D', 'AF AMER', '99', 'Student Research Program', 'Eggert, P.R.', '1D']
# ['AA0M1021A', 'AF AMER', 'M102', 'Culture, Media, and Los Angeles', 'Eggert, P.R.', '1A']
# ['AA0M1021B', 'AF AMER', 'M102', 'Culture, Media, and Los Angeles', 'Eggert, P.R.', '1B']
# ['AA0M1021C', 'AF AMER', 'M102', 'Culture, Media, and Los Angeles', 'Eggert, P.R.', '1C']
# ['AA0M1021D', 'AF AMER', 'M102', 'Culture, Media, and Los Angeles', 'Eggert, P.R.', '1D']
# ['AA1800s1A', 'AF AMER', '1800s', '(4) (Same as Theater M103A', 'Eggert, P.R.', '1A']
# ['AA1800s1B', 'AF AMER', '1800s', '(4) (Same as Theater M103A', 'Eggert, P.R.', '1B']
# ['AA1800s1C', 'AF AMER', '1800s', '(4) (Same as Theater M103A', 'Eggert, P.R.', '1C']
# ['AA1800s1D', 'AF AMER', '1800s', '(4) (Same as Theater M103A', 'Eggert, P.R.', '1D']
# ['AAM104A1A', 'AF AMER', 'M104A', 'Early African American Literature', 'Eggert, P.R.', '1A']
# ['AAM104A1B', 'AF AMER', 'M104A', 'Early African American Literature', 'Eggert, P.R.', '1B']
# ['AAM104A1C', 'AF AMER', 'M104A', 'Early African American Literature', 'Eggert, P.R.', '1C']
# ['AAM104A1D', 'AF AMER', 'M104A', 'Early African American Literature', 'Eggert, P.R.', '1D']
# ['AA1960s1A', 'AF AMER', '1960s', '(5) (Same as English M104B', 'Eggert, P.R.', '1A']
# ['AA1960s1B', 'AF AMER', '1960s', '(5) (Same as English M104B', 'Eggert, P.R.', '1B']
# ['AA1960s1C', 'AF AMER', '1960s', '(5) (Same as English M104B', 'Eggert, P.R.', '1C']
# ['AA1960s1D', 'AF AMER', '1960s', '(5) (Same as English M104B', 'Eggert, P.R.', '1D']
# ['AA1970s1A', 'AF AMER', '1970s', '(5) (Same as English M104C', 'Eggert, P.R.', '1A']
# ['AA1970s1B', 'AF AMER', '1970s', '(5) (Same as English M104C', 'Eggert, P.R.', '1B']
# ['AA1970s1C', 'AF AMER', '1970s', '(5) (Same as English M104C', 'Eggert, P.R.', '1C']
# ['AA1970s1D', 'AF AMER', '1970s', '(5) (Same as English M104C', 'Eggert, P.R.', '1D']
# ['AAM104D1A', 'AF AMER', 'M104D', 'Contemporary African American Literature', 'Eggert, P.R.', '1A']
# ['AAM104D1B', 'AF AMER', 'M104D', 'Contemporary African American Literature', 'Eggert, P.R.', '1B']
# ['AAM104D1C', 'AF AMER', 'M104D', 'Contemporary African American Literature', 'Eggert, P.R.', '1C']
# ['AAM104D1D', 'AF AMER', 'M104D', 'Contemporary African American Literature', 'Eggert, P.R.', '1D']
# ['AA0105A1A', 'AF AMER', '105A', 'Ideology and Black Consciousness', 'Eggert, P.R.', '1A']
# ['AA0105A1B', 'AF AMER', '105A', 'Ideology and Black Consciousness', 'Eggert, P.R.', '1B']
# ['AA0105A1C', 'AF AMER', '105A', 'Ideology and Black Consciousness', 'Eggert, P.R.', '1C']
# ['AA0105A1D', 'AF AMER', '105A', 'Ideology and Black Consciousness', 'Eggert, P.R.', '1D']
# ['AA0106A1A', 'AF AMER', '106A', 'Africa and World', 'Eggert, P.R.', '1A']
# ['AA0106A1B', 'AF AMER', '106A', 'Africa and World', 'Eggert, P.R.', '1B']
# ['AA0106A1C', 'AF AMER', '106A', 'Africa and World', 'Eggert, P.R.', '1C']
# ['AA0106A1D', 'AF AMER', '106A', 'Africa and World', 'Eggert, P.R.', '1D']
# ['AA0M1071A', 'AF AMER', 'M107', 'Cultural History of Rap', 'Eggert, P.R.', '1A']
# ['AA0M1071B', 'AF AMER', 'M107', 'Cultural History of Rap', 'Eggert, P.R.', '1B']
# ['AA0M1071C', 'AF AMER', 'M107', 'Cultural History of Rap', 'Eggert, P.R.', '1C']
# ['AA0M1071D', 'AF AMER', 'M107', 'Cultural History of Rap', 'Eggert, P.R.', '1D']
# ['AA001081A', 'AF AMER', '108', 'Jazz and Political Imagination', 'Eggert, P.R.', '1A']
# ['AA001081B', 'AF AMER', '108', 'Jazz and Political Imagination', 'Eggert, P.R.', '1B']
# ['AA001081C', 'AF AMER', '108', 'Jazz and Political Imagination', 'Eggert, P.R.', '1C']
# ['AA001081D', 'AF AMER', '108', 'Jazz and Political Imagination', 'Eggert, P.R.', '1D']
# ['AA0M1091A', 'AF AMER', 'M109', 'Women in Jazz', 'Eggert, P.R.', '1A']
# ['AA0M1091B', 'AF AMER', 'M109', 'Women in Jazz', 'Eggert, P.R.', '1B']
# ['AA0M1091C', 'AF AMER', 'M109', 'Women in Jazz', 'Eggert, P.R.', '1C']
# ['AA0M1091D', 'AF AMER', 'M109', 'Women in Jazz', 'Eggert, P.R.', '1D']
# ['AA0110A1A', 'AF AMER', '110A', 'Race, Science, and Society', 'Eggert, P.R.', '1A']
# ['AA0110A1B', 'AF AMER', '110A', 'Race, Science, and Society', 'Eggert, P.R.', '1B']
# ['AA0110A1C', 'AF AMER', '110A', 'Race, Science, and Society', 'Eggert, P.R.', '1C']
# ['AA0110A1D', 'AF AMER', '110A', 'Race, Science, and Society', 'Eggert, P.R.', '1D']
# ['AACM110D1A', 'AF AMER', 'CM110D', 'Posthumans', 'Eggert, P.R.', '1A']
# ['AACM110D1B', 'AF AMER', 'CM110D', 'Posthumans', 'Eggert, P.R.', '1B']
# ['AACM110D1C', 'AF AMER', 'CM110D', 'Posthumans', 'Eggert, P.R.', '1C']
# ['AACM110D1D', 'AF AMER', 'CM110D', 'Posthumans', 'Eggert, P.R.', '1D']
# ['AAC210D1A', 'AF AMER', 'C210D', 'P/NP or letter grading', 'Eggert, P.R.', '1A']
# ['AAC210D1B', 'AF AMER', 'C210D', 'P/NP or letter grading', 'Eggert, P.R.', '1B']
# ['AAC210D1C', 'AF AMER', 'C210D', 'P/NP or letter grading', 'Eggert, P.R.', '1C']
# ['AAC210D1D', 'AF AMER', 'C210D', 'P/NP or letter grading', 'Eggert, P.R.', '1D']
# ['AA0M1111A', 'AF AMER', 'M111', 'Ellingtonia', 'Eggert, P.R.', '1A']
# ['AA0M1111B', 'AF AMER', 'M111', 'Ellingtonia', 'Eggert, P.R.', '1B']
# ['AA0M1111C', 'AF AMER', 'M111', 'Ellingtonia', 'Eggert, P.R.', '1C']
# ['AA0M1111D', 'AF AMER', 'M111', 'Ellingtonia', 'Eggert, P.R.', '1D']
# ['AAM114C1A', 'AF AMER', 'M114C', 'African American Political Thought', 'Eggert, P.R.', '1A']
# ['AAM114C1B', 'AF AMER', 'M114C', 'African American Political Thought', 'Eggert, P.R.', '1B']
# ['AAM114C1C', 'AF AMER', 'M114C', 'African American Political Thought', 'Eggert, P.R.', '1C']
# ['AAM114C1D', 'AF AMER', 'M114C', 'African American Political Thought', 'Eggert, P.R.', '1D']
# ['AAM116B1A', 'AF AMER', 'M116B', 'African American Musical Heritage', 'Eggert, P.R.', '1A']
# ['AAM116B1B', 'AF AMER', 'M116B', 'African American Musical Heritage', 'Eggert, P.R.', '1B']
# ['AAM116B1C', 'AF AMER', 'M116B', 'African American Musical Heritage', 'Eggert, P.R.', '1C']
# ['AAM116B1D', 'AF AMER', 'M116B', 'African American Musical Heritage', 'Eggert, P.R.', '1D']
# ['AA0M1201A', 'AF AMER', 'M120', 'Race, Inequality, and Public Policy', 'Eggert, P.R.', '1A']
# ['AA0M1201B', 'AF AMER', 'M120', 'Race, Inequality, and Public Policy', 'Eggert, P.R.', '1B']
# ['AA0M1201C', 'AF AMER', 'M120', 'Race, Inequality, and Public Policy', 'Eggert, P.R.', '1C']
# ['AA0M1201D', 'AF AMER', 'M120', 'Race, Inequality, and Public Policy', 'Eggert, P.R.', '1D']
# ['AA0M1241A', 'AF AMER', 'M124', 'Comparative Racialization and Indigeneity', 'Eggert, P.R.', '1A']
# ['AA0M1241B', 'AF AMER', 'M124', 'Comparative Racialization and Indigeneity', 'Eggert, P.R.', '1B']
# ['AA0M1241C', 'AF AMER', 'M124', 'Comparative Racialization and Indigeneity', 'Eggert, P.R.', '1C']
# ['AA0M1241D', 'AF AMER', 'M124', 'Comparative Racialization and Indigeneity', 'Eggert, P.R.', '1D']
# ['AACM135A1A', 'AF AMER', 'CM135A', 'African American Art before 1900', 'Eggert, P.R.', '1A']
# ['AACM135A1B', 'AF AMER', 'CM135A', 'African American Art before 1900', 'Eggert, P.R.', '1B']
# ['AACM135A1C', 'AF AMER', 'CM135A', 'African American Art before 1900', 'Eggert, P.R.', '1C']
# ['AACM135A1D', 'AF AMER', 'CM135A', 'African American Art before 1900', 'Eggert, P.R.', '1D']
# ['AACM235A1A', 'AF AMER', 'CM235A', 'P/NP or letter grading', 'Eggert, P.R.', '1A']
# ['AACM235A1B', 'AF AMER', 'CM235A', 'P/NP or letter grading', 'Eggert, P.R.', '1B']
# ['AACM235A1C', 'AF AMER', 'CM235A', 'P/NP or letter grading', 'Eggert, P.R.', '1C']
# ['AACM235A1D', 'AF AMER', 'CM235A', 'P/NP or letter grading', 'Eggert, P.R.', '1D']
# ['AACM135B1A', 'AF AMER', 'CM135B', 'African American Art, 1900 to 1963', 'Eggert, P.R.', '1A']
# ['AACM135B1B', 'AF AMER', 'CM135B', 'African American Art, 1900 to 1963', 'Eggert, P.R.', '1B']
# ['AACM135B1C', 'AF AMER', 'CM135B', 'African American Art, 1900 to 1963', 'Eggert, P.R.', '1C']
# ['AACM135B1D', 'AF AMER', 'CM135B', 'African American Art, 1900 to 1963', 'Eggert, P.R.', '1D']
# ['AACM235B1A', 'AF AMER', 'CM235B', 'P/NP or letter grading', 'Eggert, P.R.', '1A']
# ['AACM235B1B', 'AF AMER', 'CM235B', 'P/NP or letter grading', 'Eggert, P.R.', '1B']
# ['AACM235B1C', 'AF AMER', 'CM235B', 'P/NP or letter grading', 'Eggert, P.R.', '1C']
# ['AACM235B1D', 'AF AMER', 'CM235B', 'P/NP or letter grading', 'Eggert, P.R.', '1D']
# ['AA0M1411A', 'AF AMER', 'M141', 'African American Women’s History', 'Eggert, P.R.', '1A']
# ['AA0M1411B', 'AF AMER', 'M141', 'African American Women’s History', 'Eggert, P.R.', '1B']
# ['AA0M1411C', 'AF AMER', 'M141', 'African American Women’s History', 'Eggert, P.R.', '1C']
# ['AA0M1411D', 'AF AMER', 'M141', 'African American Women’s History', 'Eggert, P.R.', '1D']
# ['AA0M1421A', 'AF AMER', 'M142', 'Race, Gender, and Punishment', 'Eggert, P.R.', '1A']
# ['AA0M1421B', 'AF AMER', 'M142', 'Race, Gender, and Punishment', 'Eggert, P.R.', '1B']
# ['AA0M1421C', 'AF AMER', 'M142', 'Race, Gender, and Punishment', 'Eggert, P.R.', '1C']
# ['AA0M1421D', 'AF AMER', 'M142', 'Race, Gender, and Punishment', 'Eggert, P.R.', '1D']
# ['AA0M1441A', 'AF AMER', 'M144', 'Ethnic Politics: African American Politics', 'Eggert, P.R.', '1A']
# ['AA0M1441B', 'AF AMER', 'M144', 'Ethnic Politics: African American Politics', 'Eggert, P.R.', '1B']
# ['AA0M1441C', 'AF AMER', 'M144', 'Ethnic Politics: African American Politics', 'Eggert, P.R.', '1C']
# ['AA0M1441D', 'AF AMER', 'M144', 'Ethnic Politics: African American Politics', 'Eggert, P.R.', '1D']
# ['AA000401A', 'AF AMER', '40', 'Designed for juniors/seniors', 'Eggert, P.R.', '1A']
# ['AA000401B', 'AF AMER', '40', 'Designed for juniors/seniors', 'Eggert, P.R.', '1B']
# ['AA000401C', 'AF AMER', '40', 'Designed for juniors/seniors', 'Eggert, P.R.', '1C']
# ['AA000401D', 'AF AMER', '40', 'Designed for juniors/seniors', 'Eggert, P.R.', '1D']
# ['AA0M1551A', 'AF AMER', 'M155', 'Afro-Latina/o Experience(s) in U', 'Eggert, P.R.', '1A']
# ['AA0M1551B', 'AF AMER', 'M155', 'Afro-Latina/o Experience(s) in U', 'Eggert, P.R.', '1B']
# ['AA0M1551C', 'AF AMER', 'M155', 'Afro-Latina/o Experience(s) in U', 'Eggert, P.R.', '1C']
# ['AA0M1551D', 'AF AMER', 'M155', 'Afro-Latina/o Experience(s) in U', 'Eggert, P.R.', '1D']
# ['AAM158A1A', 'AF AMER', 'M158A', 'Comparative Slavery Systems', 'Eggert, P.R.', '1A']
# ['AAM158A1B', 'AF AMER', 'M158A', 'Comparative Slavery Systems', 'Eggert, P.R.', '1B']
# ['AAM158A1C', 'AF AMER', 'M158A', 'Comparative Slavery Systems', 'Eggert, P.R.', '1C']
# ['AAM158A1D', 'AF AMER', 'M158A', 'Comparative Slavery Systems', 'Eggert, P.R.', '1D']
# ['AA0M1641A', 'AF AMER', 'M164', 'Afro-American Experience in U', 'Eggert, P.R.', '1A']
# ['AA0M1641B', 'AF AMER', 'M164', 'Afro-American Experience in U', 'Eggert, P.R.', '1B']
# ['AA0M1641C', 'AF AMER', 'M164', 'Afro-American Experience in U', 'Eggert, P.R.', '1C']
# ['AA0M1641D', 'AF AMER', 'M164', 'Afro-American Experience in U', 'Eggert, P.R.', '1D']
# ['AA0M1651A', 'AF AMER', 'M165', 'Sociology of Race and Labor', 'Eggert, P.R.', '1A']
# ['AA0M1651B', 'AF AMER', 'M165', 'Sociology of Race and Labor', 'Eggert, P.R.', '1B']
# ['AA0M1651C', 'AF AMER', 'M165', 'Sociology of Race and Labor', 'Eggert, P.R.', '1C']
# ['AA0M1651D', 'AF AMER', 'M165', 'Sociology of Race and Labor', 'Eggert, P.R.', '1D']
# ['AACM1661A', 'AF AMER', 'CM166', 'Future of Work in Decarcerated California', 'Eggert, P.R.', '1A']
# ['AACM1661B', 'AF AMER', 'CM166', 'Future of Work in Decarcerated California', 'Eggert, P.R.', '1B']
# ['AACM1661C', 'AF AMER', 'CM166', 'Future of Work in Decarcerated California', 'Eggert, P.R.', '1C']
# ['AACM1661D', 'AF AMER', 'CM166', 'Future of Work in Decarcerated California', 'Eggert, P.R.', '1D']
# ['AA0C2661A', 'AF AMER', 'C266', 'P/NP or letter grading', 'Eggert, P.R.', '1A']
# ['AA0C2661B', 'AF AMER', 'C266', 'P/NP or letter grading', 'Eggert, P.R.', '1B']
# ['AA0C2661C', 'AF AMER', 'C266', 'P/NP or letter grading', 'Eggert, P.R.', '1C']
# ['AA0C2661D', 'AF AMER', 'C266', 'P/NP or letter grading', 'Eggert, P.R.', '1D']
# ['AAC266B1A', 'AF AMER', 'C266B', 'P/NP or letter grading', 'Eggert, P.R.', '1A']
# ['AAC266B1B', 'AF AMER', 'C266B', 'P/NP or letter grading', 'Eggert, P.R.', '1B']
# ['AAC266B1C', 'AF AMER', 'C266B', 'P/NP or letter grading', 'Eggert, P.R.', '1C']
# ['AAC266B1D', 'AF AMER', 'C266B', 'P/NP or letter grading', 'Eggert, P.R.', '1D']
# ['AA0M1721A', 'AF AMER', 'M172', 'Afro-American Woman in U', 'Eggert, P.R.', '1A']
# ['AA0M1721B', 'AF AMER', 'M172', 'Afro-American Woman in U', 'Eggert, P.R.', '1B']
# ['AA0M1721C', 'AF AMER', 'M172', 'Afro-American Woman in U', 'Eggert, P.R.', '1C']
# ['AA0M1721D', 'AF AMER', 'M172', 'Afro-American Woman in U', 'Eggert, P.R.', '1D']
# ['AA0M1731A', 'AF AMER', 'M173', 'Nonviolence and Social Movements', 'Eggert, P.R.', '1A']
# ['AA0M1731B', 'AF AMER', 'M173', 'Nonviolence and Social Movements', 'Eggert, P.R.', '1B']
# ['AA0M1731C', 'AF AMER', 'M173', 'Nonviolence and Social Movements', 'Eggert, P.R.', '1C']
# ['AA0M1731D', 'AF AMER', 'M173', 'Nonviolence and Social Movements', 'Eggert, P.R.', '1D']
# ['AA001751A', 'AF AMER', '175', 'Racial and Ethnic Disparities in Healthcare', 'Eggert, P.R.', '1A']
# ['AA001751B', 'AF AMER', '175', 'Racial and Ethnic Disparities in Healthcare', 'Eggert, P.R.', '1B']
# ['AA001751C', 'AF AMER', '175', 'Racial and Ethnic Disparities in Healthcare', 'Eggert, P.R.', '1C']
# ['AA001751D', 'AF AMER', '175', 'Racial and Ethnic Disparities in Healthcare', 'Eggert, P.R.', '1D']
# ['AA001761A', 'AF AMER', '176', 'Race, Racism, and Law', 'Eggert, P.R.', '1A']
# ['AA001761B', 'AF AMER', '176', 'Race, Racism, and Law', 'Eggert, P.R.', '1B']
# ['AA001761C', 'AF AMER', '176', 'Race, Racism, and Law', 'Eggert, P.R.', '1C']
# ['AA001761D', 'AF AMER', '176', 'Race, Racism, and Law', 'Eggert, P.R.', '1D']
# ['AA001771A', 'AF AMER', '177', 'African Americans in Higher Education', 'Eggert, P.R.', '1A']
# ['AA001771B', 'AF AMER', '177', 'African Americans in Higher Education', 'Eggert, P.R.', '1B']
# ['AA001771C', 'AF AMER', '177', 'African Americans in Higher Education', 'Eggert, P.R.', '1C']
# ['AA001771D', 'AF AMER', '177', 'African Americans in Higher Education', 'Eggert, P.R.', '1D']
# ['AA0M1781A', 'AF AMER', 'M178', 'Sociology of Caribbean', 'Eggert, P.R.', '1A']
# ['AA0M1781B', 'AF AMER', 'M178', 'Sociology of Caribbean', 'Eggert, P.R.', '1B']
# ['AA0M1781C', 'AF AMER', 'M178', 'Sociology of Caribbean', 'Eggert, P.R.', '1C']
# ['AA0M1781D', 'AF AMER', 'M178', 'Sociology of Caribbean', 'Eggert, P.R.', '1D']
# ['AAM179A1A', 'AF AMER', 'M179A', 'Topics in African American Literature', 'Eggert, P.R.', '1A']
# ['AAM179A1B', 'AF AMER', 'M179A', 'Topics in African American Literature', 'Eggert, P.R.', '1B']
# ['AAM179A1C', 'AF AMER', 'M179A', 'Topics in African American Literature', 'Eggert, P.R.', '1C']
# ['AAM179A1D', 'AF AMER', 'M179A', 'Topics in African American Literature', 'Eggert, P.R.', '1D']
# ['AA0188A1A', 'AF AMER', '188A', 'Special Courses in African American Studies', 'Eggert, P.R.', '1A']
# ['AA0188A1B', 'AF AMER', '188A', 'Special Courses in African American Studies', 'Eggert, P.R.', '1B']
# ['AA0188A1C', 'AF AMER', '188A', 'Special Courses in African American Studies', 'Eggert, P.R.', '1C']
# ['AA0188A1D', 'AF AMER', '188A', 'Special Courses in African American Studies', 'Eggert, P.R.', '1D']
# ['AA0188B1A', 'AF AMER', '188B', 'Race and Public Policy', 'Eggert, P.R.', '1A']
# ['AA0188B1B', 'AF AMER', '188B', 'Race and Public Policy', 'Eggert, P.R.', '1B']
# ['AA0188B1C', 'AF AMER', '188B', 'Race and Public Policy', 'Eggert, P.R.', '1C']
# ['AA0188B1D', 'AF AMER', '188B', 'Race and Public Policy', 'Eggert, P.R.', '1D']
# ['AA0101E1A', 'AF AMER', '101E', 'Limited to junior/senior USIE facilitators', 'Eggert, P.R.', '1A']
# ['AA0101E1B', 'AF AMER', '101E', 'Limited to junior/senior USIE facilitators', 'Eggert, P.R.', '1B']
# ['AA0101E1C', 'AF AMER', '101E', 'Limited to junior/senior USIE facilitators', 'Eggert, P.R.', '1C']
# ['AA0101E1D', 'AF AMER', '101E', 'Limited to junior/senior USIE facilitators', 'Eggert, P.R.', '1D']
# ['AA001891A', 'AF AMER', '189', 'Advanced Honors Seminars', 'Eggert, P.R.', '1A']
# ['AA001891B', 'AF AMER', '189', 'Advanced Honors Seminars', 'Eggert, P.R.', '1B']
# ['AA001891C', 'AF AMER', '189', 'Advanced Honors Seminars', 'Eggert, P.R.', '1C']
# ['AA001891D', 'AF AMER', '189', 'Advanced Honors Seminars', 'Eggert, P.R.', '1D']
# ['AA0C2911A', 'AF AMER', 'C291', 'Letter grading', 'Eggert, P.R.', '1A']
# ['AA0C2911B', 'AF AMER', 'C291', 'Letter grading', 'Eggert, P.R.', '1B']
# ['AA0C2911C', 'AF AMER', 'C291', 'Letter grading', 'Eggert, P.R.', '1C']
# ['AA0C2911D', 'AF AMER', 'C291', 'Letter grading', 'Eggert, P.R.', '1D']
# ['AA001971A', 'AF AMER', '197', 'Individual Studies in Afro-American Studies', 'Eggert, P.R.', '1A']
# ['AA001971B', 'AF AMER', '197', 'Individual Studies in Afro-American Studies', 'Eggert, P.R.', '1B']
# ['AA001971C', 'AF AMER', '197', 'Individual Studies in Afro-American Studies', 'Eggert, P.R.', '1C']
# ['AA001971D', 'AF AMER', '197', 'Individual Studies in Afro-American Studies', 'Eggert, P.R.', '1D']
# ['AA001981A', 'AF AMER', '198', 'Honors Research in Afro-American Studies', 'Eggert, P.R.', '1A']
# ['AA001981B', 'AF AMER', '198', 'Honors Research in Afro-American Studies', 'Eggert, P.R.', '1B']
# ['AA001981C', 'AF AMER', '198', 'Honors Research in Afro-American Studies', 'Eggert, P.R.', '1C']
# ['AA001981D', 'AF AMER', '198', 'Honors Research in Afro-American Studies', 'Eggert, P.R.', '1D']
# ['AAM200A1A', 'AF AMER', 'M200A', 'Advanced Historiography: Afro-American', 'Eggert, P.R.', '1A']
# ['AAM200A1B', 'AF AMER', 'M200A', 'Advanced Historiography: Afro-American', 'Eggert, P.R.', '1B']
# ['AAM200A1C', 'AF AMER', 'M200A', 'Advanced Historiography: Afro-American', 'Eggert, P.R.', '1C']
# ['AAM200A1D', 'AF AMER', 'M200A', 'Advanced Historiography: Afro-American', 'Eggert, P.R.', '1D']
# ['AAM200B1A', 'AF AMER', 'M200B', 'Political Economy of Race', 'Eggert, P.R.', '1A']
# ['AAM200B1B', 'AF AMER', 'M200B', 'Political Economy of Race', 'Eggert, P.R.', '1B']
# ['AAM200B1C', 'AF AMER', 'M200B', 'Political Economy of Race', 'Eggert, P.R.', '1C']
# ['AAM200B1D', 'AF AMER', 'M200B', 'Political Economy of Race', 'Eggert, P.R.', '1D']
# ['AAM200C1A', 'AF AMER', 'M200C', 'Black Families and Relationships', 'Eggert, P.R.', '1A']
# ['AAM200C1B', 'AF AMER', 'M200C', 'Black Families and Relationships', 'Eggert, P.R.', '1B']
# ['AAM200C1C', 'AF AMER', 'M200C', 'Black Families and Relationships', 'Eggert, P.R.', '1C']
# ['AAM200C1D', 'AF AMER', 'M200C', 'Black Families and Relationships', 'Eggert, P.R.', '1D']
# ['AA0200D1A', 'AF AMER', '200D', 'African American Women’s History', 'Eggert, P.R.', '1A']
# ['AA0200D1B', 'AF AMER', '200D', 'African American Women’s History', 'Eggert, P.R.', '1B']
# ['AA0200D1C', 'AF AMER', '200D', 'African American Women’s History', 'Eggert, P.R.', '1C']
# ['AA0200D1D', 'AF AMER', '200D', 'African American Women’s History', 'Eggert, P.R.', '1D']
# ['AAM200E1A', 'AF AMER', 'M200E', 'Studies in Afro-American Literature', 'Eggert, P.R.', '1A']
# ['AAM200E1B', 'AF AMER', 'M200E', 'Studies in Afro-American Literature', 'Eggert, P.R.', '1B']
# ['AAM200E1C', 'AF AMER', 'M200E', 'Studies in Afro-American Literature', 'Eggert, P.R.', '1C']
# ['AAM200E1D', 'AF AMER', 'M200E', 'Studies in Afro-American Literature', 'Eggert, P.R.', '1D']
# ['AA0201C1A', 'AF AMER', '201C', 'Research Proposal Writing Seminar', 'Eggert, P.R.', '1A']
# ['AA0201C1B', 'AF AMER', '201C', 'Research Proposal Writing Seminar', 'Eggert, P.R.', '1B']
# ['AA0201C1C', 'AF AMER', '201C', 'Research Proposal Writing Seminar', 'Eggert, P.R.', '1C']
# ['AA0201C1D', 'AF AMER', '201C', 'Research Proposal Writing Seminar', 'Eggert, P.R.', '1D']
# ['AA0M2021A', 'AF AMER', 'M202', 'Critical Theory of African Diaspora', 'Eggert, P.R.', '1A']
# ['AA0M2021B', 'AF AMER', 'M202', 'Critical Theory of African Diaspora', 'Eggert, P.R.', '1B']
# ['AA0M2021C', 'AF AMER', 'M202', 'Critical Theory of African Diaspora', 'Eggert, P.R.', '1C']
# ['AA0M2021D', 'AF AMER', 'M202', 'Critical Theory of African Diaspora', 'Eggert, P.R.', '1D']
# ['AA019741A', 'AF AMER', '1974', '(4) Seminar, three hours', 'Eggert, P.R.', '1A']
# ['AA019741B', 'AF AMER', '1974', '(4) Seminar, three hours', 'Eggert, P.R.', '1B']
# ['AA019741C', 'AF AMER', '1974', '(4) Seminar, three hours', 'Eggert, P.R.', '1C']
# ['AA019741D', 'AF AMER', '1974', '(4) Seminar, three hours', 'Eggert, P.R.', '1D']
# ['AA1970s1A', 'AF AMER', '1970s', 'S/U or letter grading', 'Eggert, P.R.', '1A']
# ['AA1970s1B', 'AF AMER', '1970s', 'S/U or letter grading', 'Eggert, P.R.', '1B']
# ['AA1970s1C', 'AF AMER', '1970s', 'S/U or letter grading', 'Eggert, P.R.', '1C']
# ['AA1970s1D', 'AF AMER', '1970s', 'S/U or letter grading', 'Eggert, P.R.', '1D']
# ['AA0203B1A', 'AF AMER', '203B', 'Readings in African Political Economy', 'Eggert, P.R.', '1A']
# ['AA0203B1B', 'AF AMER', '203B', 'Readings in African Political Economy', 'Eggert, P.R.', '1B']
# ['AA0203B1C', 'AF AMER', '203B', 'Readings in African Political Economy', 'Eggert, P.R.', '1C']
# ['AA0203B1D', 'AF AMER', '203B', 'Readings in African Political Economy', 'Eggert, P.R.', '1D']
# ['AA1990s1A', 'AF AMER', '1990s', 'S/U or letter grading', 'Eggert, P.R.', '1A']
# ['AA1990s1B', 'AF AMER', '1990s', 'S/U or letter grading', 'Eggert, P.R.', '1B']
# ['AA1990s1C', 'AF AMER', '1990s', 'S/U or letter grading', 'Eggert, P.R.', '1C']
# ['AA1990s1D', 'AF AMER', '1990s', 'S/U or letter grading', 'Eggert, P.R.', '1D']
# ['AACM1101A', 'AF AMER', 'CM110', 'Letter grading', 'Eggert, P.R.', '1A']
# ['AACM1101B', 'AF AMER', 'CM110', 'Letter grading', 'Eggert, P.R.', '1B']
# ['AACM1101C', 'AF AMER', 'CM110', 'Letter grading', 'Eggert, P.R.', '1C']
# ['AACM1101D', 'AF AMER', 'CM110', 'Letter grading', 'Eggert, P.R.', '1D']
# ['AAC210D1A', 'AF AMER', 'C210D', 'Posthumans', 'Eggert, P.R.', '1A']
# ['AAC210D1B', 'AF AMER', 'C210D', 'Posthumans', 'Eggert, P.R.', '1B']
# ['AAC210D1C', 'AF AMER', 'C210D', 'Posthumans', 'Eggert, P.R.', '1C']
# ['AAC210D1D', 'AF AMER', 'C210D', 'Posthumans', 'Eggert, P.R.', '1D']
# ['AA0M2111A', 'AF AMER', 'M211', 'Seminar: African American Music', 'Eggert, P.R.', '1A']
# ['AA0M2111B', 'AF AMER', 'M211', 'Seminar: African American Music', 'Eggert, P.R.', '1B']
# ['AA0M2111C', 'AF AMER', 'M211', 'Seminar: African American Music', 'Eggert, P.R.', '1C']
# ['AA0M2111D', 'AF AMER', 'M211', 'Seminar: African American Music', 'Eggert, P.R.', '1D']
# ['AACM235A1A', 'AF AMER', 'CM235A', 'African American Art before 1900', 'Eggert, P.R.', '1A']
# ['AACM235A1B', 'AF AMER', 'CM235A', 'African American Art before 1900', 'Eggert, P.R.', '1B']
# ['AACM235A1C', 'AF AMER', 'CM235A', 'African American Art before 1900', 'Eggert, P.R.', '1C']
# ['AACM235A1D', 'AF AMER', 'CM235A', 'African American Art before 1900', 'Eggert, P.R.', '1D']
# ['AACM135A1A', 'AF AMER', 'CM135A', 'S/U or letter grading', 'Eggert, P.R.', '1A']
# ['AACM135A1B', 'AF AMER', 'CM135A', 'S/U or letter grading', 'Eggert, P.R.', '1B']
# ['AACM135A1C', 'AF AMER', 'CM135A', 'S/U or letter grading', 'Eggert, P.R.', '1C']
# ['AACM135A1D', 'AF AMER', 'CM135A', 'S/U or letter grading', 'Eggert, P.R.', '1D']
# ['AACM235B1A', 'AF AMER', 'CM235B', 'African American Art, 1900 to 1963', 'Eggert, P.R.', '1A']
# ['AACM235B1B', 'AF AMER', 'CM235B', 'African American Art, 1900 to 1963', 'Eggert, P.R.', '1B']
# ['AACM235B1C', 'AF AMER', 'CM235B', 'African American Art, 1900 to 1963', 'Eggert, P.R.', '1C']
# ['AACM235B1D', 'AF AMER', 'CM235B', 'African American Art, 1900 to 1963', 'Eggert, P.R.', '1D']
# ['AACM135B1A', 'AF AMER', 'CM135B', 'S/U or letter grading', 'Eggert, P.R.', '1A']
# ['AACM135B1B', 'AF AMER', 'CM135B', 'S/U or letter grading', 'Eggert, P.R.', '1B']
# ['AACM135B1C', 'AF AMER', 'CM135B', 'S/U or letter grading', 'Eggert, P.R.', '1C']
# ['AACM135B1D', 'AF AMER', 'CM135B', 'S/U or letter grading', 'Eggert, P.R.', '1D']
# ['AA002411A', 'AF AMER', '241', 'Special Topics in Afro-American Studies', 'Eggert, P.R.', '1A']
# ['AA002411B', 'AF AMER', '241', 'Special Topics in Afro-American Studies', 'Eggert, P.R.', '1B']
# ['AA002411C', 'AF AMER', '241', 'Special Topics in Afro-American Studies', 'Eggert, P.R.', '1C']
# ['AA002411D', 'AF AMER', '241', 'Special Topics in Afro-American Studies', 'Eggert, P.R.', '1D']
# ['AA0M2561A', 'AF AMER', 'M256', 'Topics in African American Art', 'Eggert, P.R.', '1A']
# ['AA0M2561B', 'AF AMER', 'M256', 'Topics in African American Art', 'Eggert, P.R.', '1B']
# ['AA0M2561C', 'AF AMER', 'M256', 'Topics in African American Art', 'Eggert, P.R.', '1C']
# ['AA0M2561D', 'AF AMER', 'M256', 'Topics in African American Art', 'Eggert, P.R.', '1D']
# ['AA0C2661A', 'AF AMER', 'C266', 'Future of Work in Decarcerated California', 'Eggert, P.R.', '1A']
# ['AA0C2661B', 'AF AMER', 'C266', 'Future of Work in Decarcerated California', 'Eggert, P.R.', '1B']
# ['AA0C2661C', 'AF AMER', 'C266', 'Future of Work in Decarcerated California', 'Eggert, P.R.', '1C']
# ['AA0C2661D', 'AF AMER', 'C266', 'Future of Work in Decarcerated California', 'Eggert, P.R.', '1D']
# ['AACM1661A', 'AF AMER', 'CM166', 'S/U or letter grading', 'Eggert, P.R.', '1A']
# ['AACM1661B', 'AF AMER', 'CM166', 'S/U or letter grading', 'Eggert, P.R.', '1B']
# ['AACM1661C', 'AF AMER', 'CM166', 'S/U or letter grading', 'Eggert, P.R.', '1C']
# ['AACM1661D', 'AF AMER', 'CM166', 'S/U or letter grading', 'Eggert, P.R.', '1D']
# ['AACM166B1A', 'AF AMER', 'CM166B', 'S/U or letter grading', 'Eggert, P.R.', '1A']
# ['AACM166B1B', 'AF AMER', 'CM166B', 'S/U or letter grading', 'Eggert, P.R.', '1B']
# ['AACM166B1C', 'AF AMER', 'CM166B', 'S/U or letter grading', 'Eggert, P.R.', '1C']
# ['AACM166B1D', 'AF AMER', 'CM166B', 'S/U or letter grading', 'Eggert, P.R.', '1D']
# ['AA0270A1A', 'AF AMER', '270A', 'Survey of Afro-American Research', 'Eggert, P.R.', '1A']
# ['AA0270A1B', 'AF AMER', '270A', 'Survey of Afro-American Research', 'Eggert, P.R.', '1B']
# ['AA0270A1C', 'AF AMER', '270A', 'Survey of Afro-American Research', 'Eggert, P.R.', '1C']
# ['AA0270A1D', 'AF AMER', '270A', 'Survey of Afro-American Research', 'Eggert, P.R.', '1D']
# ['AA0C2911A', 'AF AMER', 'C291', 'Variable Topics in Afro-American Studies', 'Eggert, P.R.', '1A']
# ['AA0C2911B', 'AF AMER', 'C291', 'Variable Topics in Afro-American Studies', 'Eggert, P.R.', '1B']
# ['AA0C2911C', 'AF AMER', 'C291', 'Variable Topics in Afro-American Studies', 'Eggert, P.R.', '1C']
# ['AA0C2911D', 'AF AMER', 'C291', 'Variable Topics in Afro-American Studies', 'Eggert, P.R.', '1D']
# ['AA0C1911A', 'AF AMER', 'C191', 'Letter grading', 'Eggert, P.R.', '1A']
# ['AA0C1911B', 'AF AMER', 'C191', 'Letter grading', 'Eggert, P.R.', '1B']
# ['AA0C1911C', 'AF AMER', 'C191', 'Letter grading', 'Eggert, P.R.', '1C']
# ['AA0C1911D', 'AF AMER', 'C191', 'Letter grading', 'Eggert, P.R.', '1D']
# ['AA003751A', 'AF AMER', '375', 'Teaching Apprentice Practicum', 'Eggert, P.R.', '1A']
# ['AA003751B', 'AF AMER', '375', 'Teaching Apprentice Practicum', 'Eggert, P.R.', '1B']
# ['AA003751C', 'AF AMER', '375', 'Teaching Apprentice Practicum', 'Eggert, P.R.', '1C']
# ['AA003751D', 'AF AMER', '375', 'Teaching Apprentice Practicum', 'Eggert, P.R.', '1D']
# ['AA005961A', 'AF AMER', '596', 'Directed Readings and Tutorials', 'Eggert, P.R.', '1A']
# ['AA005961B', 'AF AMER', '596', 'Directed Readings and Tutorials', 'Eggert, P.R.', '1B']
# ['AA005961C', 'AF AMER', '596', 'Directed Readings and Tutorials', 'Eggert, P.R.', '1C']
# ['AA005961D', 'AF AMER', '596', 'Directed Readings and Tutorials', 'Eggert, P.R.', '1D']
# ['AA005981A', 'AF AMER', '598', 'Research for and Preparation of MA Thesis', 'Eggert, P.R.', '1A']
# ['AA005981B', 'AF AMER', '598', 'Research for and Preparation of MA Thesis', 'Eggert, P.R.', '1B']
# ['AA005981C', 'AF AMER', '598', 'Research for and Preparation of MA Thesis', 'Eggert, P.R.', '1C']
# ['AA005981D', 'AF AMER', '598', 'Research for and Preparation of MA Thesis', 'Eggert, P.R.', '1D']
# ['AA0201A1A', 'AF AMER', '201A', 'Africa and Disciplines', 'Eggert, P.R.', '1A']
# ['AA0201A1B', 'AF AMER', '201A', 'Africa and Disciplines', 'Eggert, P.R.', '1B']
# ['AA0201A1C', 'AF AMER', '201A', 'Africa and Disciplines', 'Eggert, P.R.', '1C']
# ['AA0201A1D', 'AF AMER', '201A', 'Africa and Disciplines', 'Eggert, P.R.', '1D']
# ['AA0201B1A', 'AF AMER', '201B', 'Africa and Professions', 'Eggert, P.R.', '1A']
# ['AA0201B1B', 'AF AMER', '201B', 'Africa and Professions', 'Eggert, P.R.', '1B']
# ['AA0201B1C', 'AF AMER', '201B', 'Africa and Professions', 'Eggert, P.R.', '1C']
# ['AA0201B1D', 'AF AMER', '201B', 'Africa and Professions', 'Eggert, P.R.', '1D']
# ['AA002961A', 'AF AMER', '296', 'Africanist Working Group', 'Eggert, P.R.', '1A']
# ['AA002961B', 'AF AMER', '296', 'Africanist Working Group', 'Eggert, P.R.', '1B']
# ['AA002961C', 'AF AMER', '296', 'Africanist Working Group', 'Eggert, P.R.', '1C']
# ['AA002961D', 'AF AMER', '296', 'Africanist Working Group', 'Eggert, P.R.', '1D']
# ['AA003751A', 'AF AMER', '375', 'Teaching Apprentice Practicum', 'Eggert, P.R.', '1A']
# ['AA003751B', 'AF AMER', '375', 'Teaching Apprentice Practicum', 'Eggert, P.R.', '1B']
# ['AA003751C', 'AF AMER', '375', 'Teaching Apprentice Practicum', 'Eggert, P.R.', '1C']
# ['AA003751D', 'AF AMER', '375', 'Teaching Apprentice Practicum', 'Eggert, P.R.', '1D']
# ['AA005961A', 'AF AMER', '596', 'Directed Individual Study or Research', 'Eggert, P.R.', '1A']
# ['AA005961B', 'AF AMER', '596', 'Directed Individual Study or Research', 'Eggert, P.R.', '1B']
# ['AA005961C', 'AF AMER', '596', 'Directed Individual Study or Research', 'Eggert, P.R.', '1C']
# ['AA005961D', 'AF AMER', '596', 'Directed Individual Study or Research', 'Eggert, P.R.', '1D']
# ['AA005981A', 'AF AMER', '598', 'Research for and Preparation of MA Thesis', 'Eggert, P.R.', '1A']
# ['AA005981B', 'AF AMER', '598', 'Research for and Preparation of MA Thesis', 'Eggert, P.R.', '1B']
# ['AA005981C', 'AF AMER', '598', 'Research for and Preparation of MA Thesis', 'Eggert, P.R.', '1C']
# ['AA005981D', 'AF AMER', '598', 'Research for and Preparation of MA Thesis', 'Eggert, P.R.', '1D']
# ['AA00M101A', 'AF AMER', 'M10', 'Introduction to American Indian Studies', 'Eggert, P.R.', '1A']
# ['AA00M101B', 'AF AMER', 'M10', 'Introduction to American Indian Studies', 'Eggert, P.R.', '1B']
# ['AA00M101C', 'AF AMER', 'M10', 'Introduction to American Indian Studies', 'Eggert, P.R.', '1C']
# ['AA00M101D', 'AF AMER', 'M10', 'Introduction to American Indian Studies', 'Eggert, P.R.', '1D']
# ['AA00M181A', 'AF AMER', 'M18', 'Leadership and Student-Initiated Retention', 'Eggert, P.R.', '1A']
# ['AA00M181B', 'AF AMER', 'M18', 'Leadership and Student-Initiated Retention', 'Eggert, P.R.', '1B']
# ['AA00M181C', 'AF AMER', 'M18', 'Leadership and Student-Initiated Retention', 'Eggert, P.R.', '1C']
# ['AA00M181D', 'AF AMER', 'M18', 'Leadership and Student-Initiated Retention', 'Eggert, P.R.', '1D']
# ['CS000011A', 'COM SCI', '1', 'Freshman Computer Science Seminar', 'Eggert, P.R.', '1A']
# ['CS000011B', 'COM SCI', '1', 'Freshman Computer Science Seminar', 'Eggert, P.R.', '1B']
# ['CS000011C', 'COM SCI', '1', 'Freshman Computer Science Seminar', 'Eggert, P.R.', '1C']
# ['CS000011D', 'COM SCI', '1', 'Freshman Computer Science Seminar', 'Eggert, P.R.', '1D']
# ['CS000191A', 'COM SCI', '19', 'Fiat Lux Freshman Seminars', 'Eggert, P.R.', '1A']
# ['CS000191B', 'COM SCI', '19', 'Fiat Lux Freshman Seminars', 'Eggert, P.R.', '1B']
# ['CS000191C', 'COM SCI', '19', 'Fiat Lux Freshman Seminars', 'Eggert, P.R.', '1C']
# ['CS000191D', 'COM SCI', '19', 'Fiat Lux Freshman Seminars', 'Eggert, P.R.', '1D']
# ['CS000301A', 'COM SCI', '30', 'Principles and Practices of Computing', 'Eggert, P.R.', '1A']
# ['CS000301B', 'COM SCI', '30', 'Principles and Practices of Computing', 'Eggert, P.R.', '1B']
# ['CS000301C', 'COM SCI', '30', 'Principles and Practices of Computing', 'Eggert, P.R.', '1C']
# ['CS000301D', 'COM SCI', '30', 'Principles and Practices of Computing', 'Eggert, P.R.', '1D']
# ['CS000311A', 'COM SCI', '31', 'Introduction to Computer Science I', 'Eggert, P.R.', '1A']
# ['CS000311B', 'COM SCI', '31', 'Introduction to Computer Science I', 'Eggert, P.R.', '1B']
# ['CS000311C', 'COM SCI', '31', 'Introduction to Computer Science I', 'Eggert, P.R.', '1C']
# ['CS000311D', 'COM SCI', '31', 'Introduction to Computer Science I', 'Eggert, P.R.', '1D']
# ['CS000321A', 'COM SCI', '32', 'Introduction to Computer Science II', 'Eggert, P.R.', '1A']
# ['CS000321B', 'COM SCI', '32', 'Introduction to Computer Science II', 'Eggert, P.R.', '1B']
# ['CS000321C', 'COM SCI', '32', 'Introduction to Computer Science II', 'Eggert, P.R.', '1C']
# ['CS000321D', 'COM SCI', '32', 'Introduction to Computer Science II', 'Eggert, P.R.', '1D']
# ['CS000331A', 'COM SCI', '33', 'Introduction to Computer Organization', 'Eggert, P.R.', '1A']
# ['CS000331B', 'COM SCI', '33', 'Introduction to Computer Organization', 'Eggert, P.R.', '1B']
# ['CS000331C', 'COM SCI', '33', 'Introduction to Computer Organization', 'Eggert, P.R.', '1C']
# ['CS000331D', 'COM SCI', '33', 'Introduction to Computer Organization', 'Eggert, P.R.', '1D']
# ['CS0035L1A', 'COM SCI', '35L', 'Software Construction', 'Eggert, P.R.', '1A']
# ['CS0035L1B', 'COM SCI', '35L', 'Software Construction', 'Eggert, P.R.', '1B']
# ['CS0035L1C', 'COM SCI', '35L', 'Software Construction', 'Eggert, P.R.', '1C']
# ['CS0035L1D', 'COM SCI', '35L', 'Software Construction', 'Eggert, P.R.', '1D']
# ['CS0M51A1A', 'COM SCI', 'M51A', 'Logic Design of Digital Systems', 'Eggert, P.R.', '1A']
# ['CS0M51A1B', 'COM SCI', 'M51A', 'Logic Design of Digital Systems', 'Eggert, P.R.', '1B']
# ['CS0M51A1C', 'COM SCI', 'M51A', 'Logic Design of Digital Systems', 'Eggert, P.R.', '1C']
# ['CS0M51A1D', 'COM SCI', 'M51A', 'Logic Design of Digital Systems', 'Eggert, P.R.', '1D']
# ['CS000971A', 'COM SCI', '97', 'Variable Topics in Computer Science', 'Eggert, P.R.', '1A']
# ['CS000971B', 'COM SCI', '97', 'Variable Topics in Computer Science', 'Eggert, P.R.', '1B']
# ['CS000971C', 'COM SCI', '97', 'Variable Topics in Computer Science', 'Eggert, P.R.', '1C']
# ['CS000971D', 'COM SCI', '97', 'Variable Topics in Computer Science', 'Eggert, P.R.', '1D']
# ['CS000991A', 'COM SCI', '99', 'Student Research Program', 'Eggert, P.R.', '1A']
# ['CS000991B', 'COM SCI', '99', 'Student Research Program', 'Eggert, P.R.', '1B']
# ['CS000991C', 'COM SCI', '99', 'Student Research Program', 'Eggert, P.R.', '1C']
# ['CS000991D', 'COM SCI', '99', 'Student Research Program', 'Eggert, P.R.', '1D']
# ['CS001111A', 'COM SCI', '111', 'Operating Systems Principles', 'Eggert, P.R.', '1A']
# ['CS001111B', 'COM SCI', '111', 'Operating Systems Principles', 'Eggert, P.R.', '1B']
# ['CS001111C', 'COM SCI', '111', 'Operating Systems Principles', 'Eggert, P.R.', '1C']
# ['CS001111D', 'COM SCI', '111', 'Operating Systems Principles', 'Eggert, P.R.', '1D']
# ['CS001121A', 'COM SCI', '112', 'Modeling Uncertainty in Information Systems', 'Eggert, P.R.', '1A']
# ['CS001121B', 'COM SCI', '112', 'Modeling Uncertainty in Information Systems', 'Eggert, P.R.', '1B']
# ['CS001121C', 'COM SCI', '112', 'Modeling Uncertainty in Information Systems', 'Eggert, P.R.', '1C']
# ['CS001121D', 'COM SCI', '112', 'Modeling Uncertainty in Information Systems', 'Eggert, P.R.', '1D']
# ['CS0100A1A', 'COM SCI', '100A', 'Designed for juniors/seniors', 'Eggert, P.R.', '1A']
# ['CS0100A1B', 'COM SCI', '100A', 'Designed for juniors/seniors', 'Eggert, P.R.', '1B']
# ['CS0100A1C', 'COM SCI', '100A', 'Designed for juniors/seniors', 'Eggert, P.R.', '1C']
# ['CS0100A1D', 'COM SCI', '100A', 'Designed for juniors/seniors', 'Eggert, P.R.', '1D']
# ['CS001171A', 'COM SCI', '117', 'Computer Networks: Physical Layer', 'Eggert, P.R.', '1A']
# ['CS001171B', 'COM SCI', '117', 'Computer Networks: Physical Layer', 'Eggert, P.R.', '1B']
# ['CS001171C', 'COM SCI', '117', 'Computer Networks: Physical Layer', 'Eggert, P.R.', '1C']
# ['CS001171D', 'COM SCI', '117', 'Computer Networks: Physical Layer', 'Eggert, P.R.', '1D']
# ['CS001181A', 'COM SCI', '118', 'Computer Network Fundamentals', 'Eggert, P.R.', '1A']
# ['CS001181B', 'COM SCI', '118', 'Computer Network Fundamentals', 'Eggert, P.R.', '1B']
# ['CS001181C', 'COM SCI', '118', 'Computer Network Fundamentals', 'Eggert, P.R.', '1C']
# ['CS001181D', 'COM SCI', '118', 'Computer Network Fundamentals', 'Eggert, P.R.', '1D']
# ['CSCM1211A', 'COM SCI', 'CM121', 'Introduction to Bioinformatics', 'Eggert, P.R.', '1A']
# ['CSCM1211B', 'COM SCI', 'CM121', 'Introduction to Bioinformatics', 'Eggert, P.R.', '1B']
# ['CSCM1211C', 'COM SCI', 'CM121', 'Introduction to Bioinformatics', 'Eggert, P.R.', '1C']
# ['CSCM1211D', 'COM SCI', 'CM121', 'Introduction to Bioinformatics', 'Eggert, P.R.', '1D']
# ['CS0C1221A', 'COM SCI', 'C122', 'Algorithms in Computational Genomics', 'Eggert, P.R.', '1A']
# ['CS0C1221B', 'COM SCI', 'C122', 'Algorithms in Computational Genomics', 'Eggert, P.R.', '1B']
# ['CS0C1221C', 'COM SCI', 'C122', 'Algorithms in Computational Genomics', 'Eggert, P.R.', '1C']
# ['CS0C1221D', 'COM SCI', 'C122', 'Algorithms in Computational Genomics', 'Eggert, P.R.', '1D']
# ['CS0100A1A', 'COM SCI', '100A', 'Course C121 is not requisite to C122', 'Eggert, P.R.', '1A']
# ['CS0100A1B', 'COM SCI', '100A', 'Course C121 is not requisite to C122', 'Eggert, P.R.', '1B']
# ['CS0100A1C', 'COM SCI', '100A', 'Course C121 is not requisite to C122', 'Eggert, P.R.', '1C']
# ['CS0100A1D', 'COM SCI', '100A', 'Course C121 is not requisite to C122', 'Eggert, P.R.', '1D']
# ['CS0C2221A', 'COM SCI', 'C222', 'Letter grading', 'Eggert, P.R.', '1A']
# ['CS0C2221B', 'COM SCI', 'C222', 'Letter grading', 'Eggert, P.R.', '1B']
# ['CS0C2221C', 'COM SCI', 'C222', 'Letter grading', 'Eggert, P.R.', '1C']
# ['CS0C2221D', 'COM SCI', 'C222', 'Letter grading', 'Eggert, P.R.', '1D']
# ['CSCM1241A', 'COM SCI', 'CM124', 'Machine Learning Applications in Genetics', 'Eggert, P.R.', '1A']
# ['CSCM1241B', 'COM SCI', 'CM124', 'Machine Learning Applications in Genetics', 'Eggert, P.R.', '1B']
# ['CSCM1241C', 'COM SCI', 'CM124', 'Machine Learning Applications in Genetics', 'Eggert, P.R.', '1C']
# ['CSCM1241D', 'COM SCI', 'CM124', 'Machine Learning Applications in Genetics', 'Eggert, P.R.', '1D']
# ['CS001301A', 'COM SCI', '130', 'Software Engineering', 'Eggert, P.R.', '1A']
# ['CS001301B', 'COM SCI', '130', 'Software Engineering', 'Eggert, P.R.', '1B']
# ['CS001301C', 'COM SCI', '130', 'Software Engineering', 'Eggert, P.R.', '1C']
# ['CS001301D', 'COM SCI', '130', 'Software Engineering', 'Eggert, P.R.', '1D']
# ['CS001311A', 'COM SCI', '131', 'Programming Languages', 'Eggert, P.R.', '1A']
# ['CS001311B', 'COM SCI', '131', 'Programming Languages', 'Eggert, P.R.', '1B']
# ['CS001311C', 'COM SCI', '131', 'Programming Languages', 'Eggert, P.R.', '1C']
# ['CS001311D', 'COM SCI', '131', 'Programming Languages', 'Eggert, P.R.', '1D']
# ['CS001321A', 'COM SCI', '132', 'Compiler Construction', 'Eggert, P.R.', '1A']
# ['CS001321B', 'COM SCI', '132', 'Compiler Construction', 'Eggert, P.R.', '1B']
# ['CS001321C', 'COM SCI', '132', 'Compiler Construction', 'Eggert, P.R.', '1C']
# ['CS001321D', 'COM SCI', '132', 'Compiler Construction', 'Eggert, P.R.', '1D']
# ['CS001331A', 'COM SCI', '133', 'Parallel and Distributed Computing', 'Eggert, P.R.', '1A']
# ['CS001331B', 'COM SCI', '133', 'Parallel and Distributed Computing', 'Eggert, P.R.', '1B']
# ['CS001331C', 'COM SCI', '133', 'Parallel and Distributed Computing', 'Eggert, P.R.', '1C']
# ['CS001331D', 'COM SCI', '133', 'Parallel and Distributed Computing', 'Eggert, P.R.', '1D']
# ['CS001341A', 'COM SCI', '134', 'Distributed Systems', 'Eggert, P.R.', '1A']
# ['CS001341B', 'COM SCI', '134', 'Distributed Systems', 'Eggert, P.R.', '1B']
# ['CS001341C', 'COM SCI', '134', 'Distributed Systems', 'Eggert, P.R.', '1C']
# ['CS001341D', 'COM SCI', '134', 'Distributed Systems', 'Eggert, P.R.', '1D']
# ['CS001361A', 'COM SCI', '136', 'Introduction to Computer Security', 'Eggert, P.R.', '1A']
# ['CS001361B', 'COM SCI', '136', 'Introduction to Computer Security', 'Eggert, P.R.', '1B']
# ['CS001361C', 'COM SCI', '136', 'Introduction to Computer Security', 'Eggert, P.R.', '1C']
# ['CS001361D', 'COM SCI', '136', 'Introduction to Computer Security', 'Eggert, P.R.', '1D']
# ['CSC137A1A', 'COM SCI', 'C137A', 'Prototyping Programming Languages', 'Eggert, P.R.', '1A']
# ['CSC137A1B', 'COM SCI', 'C137A', 'Prototyping Programming Languages', 'Eggert, P.R.', '1B']
# ['CSC137A1C', 'COM SCI', 'C137A', 'Prototyping Programming Languages', 'Eggert, P.R.', '1C']
# ['CSC137A1D', 'COM SCI', 'C137A', 'Prototyping Programming Languages', 'Eggert, P.R.', '1D']
# ['CSC237A1A', 'COM SCI', 'C237A', 'Letter grading', 'Eggert, P.R.', '1A']
# ['CSC237A1B', 'COM SCI', 'C237A', 'Letter grading', 'Eggert, P.R.', '1B']
# ['CSC237A1C', 'COM SCI', 'C237A', 'Letter grading', 'Eggert, P.R.', '1C']
# ['CSC237A1D', 'COM SCI', 'C237A', 'Letter grading', 'Eggert, P.R.', '1D']
# ['CSC137B1A', 'COM SCI', 'C137B', 'Programming Language Design', 'Eggert, P.R.', '1A']
# ['CSC137B1B', 'COM SCI', 'C137B', 'Programming Language Design', 'Eggert, P.R.', '1B']
# ['CSC137B1C', 'COM SCI', 'C137B', 'Programming Language Design', 'Eggert, P.R.', '1C']
# ['CSC137B1D', 'COM SCI', 'C137B', 'Programming Language Design', 'Eggert, P.R.', '1D']
# ['CS001431A', 'COM SCI', '143', 'Data Management Systems', 'Eggert, P.R.', '1A']
# ['CS001431B', 'COM SCI', '143', 'Data Management Systems', 'Eggert, P.R.', '1B']
# ['CS001431C', 'COM SCI', '143', 'Data Management Systems', 'Eggert, P.R.', '1C']
# ['CS001431D', 'COM SCI', '143', 'Data Management Systems', 'Eggert, P.R.', '1D']
# ['CS001441A', 'COM SCI', '144', 'Web Applications', 'Eggert, P.R.', '1A']
# ['CS001441B', 'COM SCI', '144', 'Web Applications', 'Eggert, P.R.', '1B']
# ['CS001441C', 'COM SCI', '144', 'Web Applications', 'Eggert, P.R.', '1C']
# ['CS001441D', 'COM SCI', '144', 'Web Applications', 'Eggert, P.R.', '1D']
# ['CS001451A', 'COM SCI', '145', 'Introduction to Data Mining', 'Eggert, P.R.', '1A']
# ['CS001451B', 'COM SCI', '145', 'Introduction to Data Mining', 'Eggert, P.R.', '1B']
# ['CS001451C', 'COM SCI', '145', 'Introduction to Data Mining', 'Eggert, P.R.', '1C']
# ['CS001451D', 'COM SCI', '145', 'Introduction to Data Mining', 'Eggert, P.R.', '1D']
# ['CS0M1461A', 'COM SCI', 'M146', 'Introduction to Machine Learning', 'Eggert, P.R.', '1A']
# ['CS0M1461B', 'COM SCI', 'M146', 'Introduction to Machine Learning', 'Eggert, P.R.', '1B']
# ['CS0M1461C', 'COM SCI', 'M146', 'Introduction to Machine Learning', 'Eggert, P.R.', '1C']
# ['CS0M1461D', 'COM SCI', 'M146', 'Introduction to Machine Learning', 'Eggert, P.R.', '1D']
# ['CS0033A1A', 'COM SCI', '33A', 'Introduction to breadth of data science', 'Eggert, P.R.', '1A']
# ['CS0033A1B', 'COM SCI', '33A', 'Introduction to breadth of data science', 'Eggert, P.R.', '1B']
# ['CS0033A1C', 'COM SCI', '33A', 'Introduction to breadth of data science', 'Eggert, P.R.', '1C']
# ['CS0033A1D', 'COM SCI', '33A', 'Introduction to breadth of data science', 'Eggert, P.R.', '1D']
# ['CS0M1481A', 'COM SCI', 'M148', 'Introduction to Data Science', 'Eggert, P.R.', '1A']
# ['CS0M1481B', 'COM SCI', 'M148', 'Introduction to Data Science', 'Eggert, P.R.', '1B']
# ['CS0M1481C', 'COM SCI', 'M148', 'Introduction to Data Science', 'Eggert, P.R.', '1C']
# ...
# ['PS0280A1D', 'POLI SCI', '280A', 'Race and Ethnic Politics Field Seminar 1', 'Eggert, P.R.', '1D', '']
# ['PS0280A1C', 'POLI SCI', '280A', 'Race and Ethnic Politics Field Seminar 1', 'Eggert, P.R.', '1C', '']
# ['PS0280A1B', 'POLI SCI', '280A', 'Race and Ethnic Politics Field Seminar 1', 'Eggert, P.R.', '1B', '']
# ['PS0280A1C', 'POLI SCI', '280A', 'Race and Ethnic Politics Field Seminar 1', 'Eggert, P.R.', '1C', '']
# ['PS0280A1D', 'POLI SCI', '280A', 'Race and Ethnic Politics Field Seminar 1', 'Eggert, P.R.', '1D', '']
# ['PS0280A1D', 'POLI SCI', '280A', 'Race and Ethnic Politics Field Seminar 1', 'Eggert, P.R.', '1D', '']
# ['PS0280A1B', 'POLI SCI', '280A', 'Race and Ethnic Politics Field Seminar 1', 'Eggert, P.R.', '1B', '']
# ['PS0280A1C', 'POLI SCI', '280A', 'Race and Ethnic Politics Field Seminar 1', 'Eggert, P.R.', '1C', '']
# ['PS0280A1D', 'POLI SCI', '280A', 'Race and Ethnic Politics Field Seminar 1', 'Eggert, P.R.', '1D', '']
# ['PS0280B1A', 'POLI SCI', '280B', 'Research Methods in Race-Ethnicity Politics', 'Eggert, P.R.', '1A', '']
# ['PS0280B1B', 'POLI SCI', '280B', 'Research Methods in Race-Ethnicity Politics', 'Eggert, P.R.', '1B', '']
# ['PS0280B1C', 'POLI SCI', '280B', 'Research Methods in Race-Ethnicity Politics', 'Eggert, P.R.', '1C', '']
# ['PS0280B1D', 'POLI SCI', '280B', 'Research Methods in Race-Ethnicity Politics', 'Eggert, P.R.', '1D', '']
# ['PS0280B1B', 'POLI SCI', '280B', 'Research Methods in Race-Ethnicity Politics', 'Eggert, P.R.', '1B', '']
# ['PS0280B1B', 'POLI SCI', '280B', 'Research Methods in Race-Ethnicity Politics', 'Eggert, P.R.', '1B', '']
# ['PS0280B1C', 'POLI SCI', '280B', 'Research Methods in Race-Ethnicity Politics', 'Eggert, P.R.', '1C', '']
# ['PS0280B1D', 'POLI SCI', '280B', 'Research Methods in Race-Ethnicity Politics', 'Eggert, P.R.', '1D', '']
# ['PS0280B1C', 'POLI SCI', '280B', 'Research Methods in Race-Ethnicity Politics', 'Eggert, P.R.', '1C', '']
# ['PS0280B1B', 'POLI SCI', '280B', 'Research Methods in Race-Ethnicity Politics', 'Eggert, P.R.', '1B', '']
# ['PS0280B1C', 'POLI SCI', '280B', 'Research Methods in Race-Ethnicity Politics', 'Eggert, P.R.', '1C', '']
# ['PS0280B1D', 'POLI SCI', '280B', 'Research Methods in Race-Ethnicity Politics', 'Eggert, P.R.', '1D', '']
# ['PS0280B1D', 'POLI SCI', '280B', 'Research Methods in Race-Ethnicity Politics', 'Eggert, P.R.', '1D', '']
# ['PS0280B1B', 'POLI SCI', '280B', 'Research Methods in Race-Ethnicity Politics', 'Eggert, P.R.', '1B', '']
# ['PS0280B1C', 'POLI SCI', '280B', 'Research Methods in Race-Ethnicity Politics', 'Eggert, P.R.', '1C', '']
# ['PS0280B1D', 'POLI SCI', '280B', 'Research Methods in Race-Ethnicity Politics', 'Eggert, P.R.', '1D', '']
# ['PS002901A', 'POLI SCI', '290', 'Modern Political Economy', 'Eggert, P.R.', '1A', '']
# ['PS002901B', 'POLI SCI', '290', 'Modern Political Economy', 'Eggert, P.R.', '1B', '']
# ['PS002901C', 'POLI SCI', '290', 'Modern Political Economy', 'Eggert, P.R.', '1C', '']
# ['PS002901D', 'POLI SCI', '290', 'Modern Political Economy', 'Eggert, P.R.', '1D', '']
# ['PS002901B', 'POLI SCI', '290', 'Modern Political Economy', 'Eggert, P.R.', '1B', '']
# ['PS002901B', 'POLI SCI', '290', 'Modern Political Economy', 'Eggert, P.R.', '1B', '']
# ['PS002901C', 'POLI SCI', '290', 'Modern Political Economy', 'Eggert, P.R.', '1C', '']
# ['PS002901D', 'POLI SCI', '290', 'Modern Political Economy', 'Eggert, P.R.', '1D', '']
# ['PS002901C', 'POLI SCI', '290', 'Modern Political Economy', 'Eggert, P.R.', '1C', '']
# ['PS002901B', 'POLI SCI', '290', 'Modern Political Economy', 'Eggert, P.R.', '1B', '']
# ['PS002901C', 'POLI SCI', '290', 'Modern Political Economy', 'Eggert, P.R.', '1C', '']
# ['PS002901D', 'POLI SCI', '290', 'Modern Political Economy', 'Eggert, P.R.', '1D', '']
# ['PS002901D', 'POLI SCI', '290', 'Modern Political Economy', 'Eggert, P.R.', '1D', '']
# ['PS002901B', 'POLI SCI', '290', 'Modern Political Economy', 'Eggert, P.R.', '1B', '']
# ['PS002901C', 'POLI SCI', '290', 'Modern Political Economy', 'Eggert, P.R.', '1C', '']
# ['PS002901D', 'POLI SCI', '290', 'Modern Political Economy', 'Eggert, P.R.', '1D', '']
# ['PS002931A', 'POLI SCI', '293', 'Great Ideas in Social Sciences', 'Eggert, P.R.', '1A', '']
# ['PS002931B', 'POLI SCI', '293', 'Great Ideas in Social Sciences', 'Eggert, P.R.', '1B', '']
# ['PS002931C', 'POLI SCI', '293', 'Great Ideas in Social Sciences', 'Eggert, P.R.', '1C', '']
# ['PS002931D', 'POLI SCI', '293', 'Great Ideas in Social Sciences', 'Eggert, P.R.', '1D', '']
# ['PS002931B', 'POLI SCI', '293', 'Great Ideas in Social Sciences', 'Eggert, P.R.', '1B', '']
# ['PS002931B', 'POLI SCI', '293', 'Great Ideas in Social Sciences', 'Eggert, P.R.', '1B', '']
# ['PS002931C', 'POLI SCI', '293', 'Great Ideas in Social Sciences', 'Eggert, P.R.', '1C', '']
# ['PS002931D', 'POLI SCI', '293', 'Great Ideas in Social Sciences', 'Eggert, P.R.', '1D', '']
# ['PS002931C', 'POLI SCI', '293', 'Great Ideas in Social Sciences', 'Eggert, P.R.', '1C', '']
# ['PS002931B', 'POLI SCI', '293', 'Great Ideas in Social Sciences', 'Eggert, P.R.', '1B', '']
# ['PS002931C', 'POLI SCI', '293', 'Great Ideas in Social Sciences', 'Eggert, P.R.', '1C', '']
# ['PS002931D', 'POLI SCI', '293', 'Great Ideas in Social Sciences', 'Eggert, P.R.', '1D', '']
# ['PS002931D', 'POLI SCI', '293', 'Great Ideas in Social Sciences', 'Eggert, P.R.', '1D', '']
# ['PS002931B', 'POLI SCI', '293', 'Great Ideas in Social Sciences', 'Eggert, P.R.', '1B', '']
# ['PS002931C', 'POLI SCI', '293', 'Great Ideas in Social Sciences', 'Eggert, P.R.', '1C', '']
# ['PS002931D', 'POLI SCI', '293', 'Great Ideas in Social Sciences', 'Eggert, P.R.', '1D', '']
# ['PS003751A', 'POLI SCI', '375', 'Teaching Apprentice Practicum', 'Eggert, P.R.', '1A', '']
# ['PS003751B', 'POLI SCI', '375', 'Teaching Apprentice Practicum', 'Eggert, P.R.', '1B', '']
# ['PS003751C', 'POLI SCI', '375', 'Teaching Apprentice Practicum', 'Eggert, P.R.', '1C', '']
# ['PS003751D', 'POLI SCI', '375', 'Teaching Apprentice Practicum', 'Eggert, P.R.', '1D', '']
# ['PS003751B', 'POLI SCI', '375', 'Teaching Apprentice Practicum', 'Eggert, P.R.', '1B', '']
# ['PS003751B', 'POLI SCI', '375', 'Teaching Apprentice Practicum', 'Eggert, P.R.', '1B', '']
# ['PS003751C', 'POLI SCI', '375', 'Teaching Apprentice Practicum', 'Eggert, P.R.', '1C', '']
# ['PS003751D', 'POLI SCI', '375', 'Teaching Apprentice Practicum', 'Eggert, P.R.', '1D', '']
# ['PS003751C', 'POLI SCI', '375', 'Teaching Apprentice Practicum', 'Eggert, P.R.', '1C', '']
# ['PS003751B', 'POLI SCI', '375', 'Teaching Apprentice Practicum', 'Eggert, P.R.', '1B', '']
# ['PS003751C', 'POLI SCI', '375', 'Teaching Apprentice Practicum', 'Eggert, P.R.', '1C', '']
# ['PS003751D', 'POLI SCI', '375', 'Teaching Apprentice Practicum', 'Eggert, P.R.', '1D', '']
# ['PS003751D', 'POLI SCI', '375', 'Teaching Apprentice Practicum', 'Eggert, P.R.', '1D', '']
# ['PS003751B', 'POLI SCI', '375', 'Teaching Apprentice Practicum', 'Eggert, P.R.', '1B', '']
# ['PS003751C', 'POLI SCI', '375', 'Teaching Apprentice Practicum', 'Eggert, P.R.', '1C', '']
# ['PS003751D', 'POLI SCI', '375', 'Teaching Apprentice Practicum', 'Eggert, P.R.', '1D', '']
# ['PS004951A', 'POLI SCI', '495', 'Teaching Political Science', 'Eggert, P.R.', '1A', '']
# ['PS004951B', 'POLI SCI', '495', 'Teaching Political Science', 'Eggert, P.R.', '1B', '']
# ['PS004951C', 'POLI SCI', '495', 'Teaching Political Science', 'Eggert, P.R.', '1C', '']
# ['PS004951D', 'POLI SCI', '495', 'Teaching Political Science', 'Eggert, P.R.', '1D', '']
# ['PS004951B', 'POLI SCI', '495', 'Teaching Political Science', 'Eggert, P.R.', '1B', '']
# ['PS004951B', 'POLI SCI', '495', 'Teaching Political Science', 'Eggert, P.R.', '1B', '']
# ['PS004951C', 'POLI SCI', '495', 'Teaching Political Science', 'Eggert, P.R.', '1C', '']
# ['PS004951D', 'POLI SCI', '495', 'Teaching Political Science', 'Eggert, P.R.', '1D', '']
# ['PS004951C', 'POLI SCI', '495', 'Teaching Political Science', 'Eggert, P.R.', '1C', '']
# ['PS004951B', 'POLI SCI', '495', 'Teaching Political Science', 'Eggert, P.R.', '1B', '']
# ['PS004951C', 'POLI SCI', '495', 'Teaching Political Science', 'Eggert, P.R.', '1C', '']
# ['PS004951D', 'POLI SCI', '495', 'Teaching Political Science', 'Eggert, P.R.', '1D', '']
# ['PS004951D', 'POLI SCI', '495', 'Teaching Political Science', 'Eggert, P.R.', '1D', '']
# ['PS004951B', 'POLI SCI', '495', 'Teaching Political Science', 'Eggert, P.R.', '1B', '']
# ['PS004951C', 'POLI SCI', '495', 'Teaching Political Science', 'Eggert, P.R.', '1C', '']
# ['PS004951D', 'POLI SCI', '495', 'Teaching Political Science', 'Eggert, P.R.', '1D', '']
# ['PS0495A1A', 'POLI SCI', '495A', 'Teaching Political Science 1', 'Eggert, P.R.', '1A', '']
# ['PS0495A1B', 'POLI SCI', '495A', 'Teaching Political Science 1', 'Eggert, P.R.', '1B', '']
# ['PS0495A1C', 'POLI SCI', '495A', 'Teaching Political Science 1', 'Eggert, P.R.', '1C', '']
# ['PS0495A1D', 'POLI SCI', '495A', 'Teaching Political Science 1', 'Eggert, P.R.', '1D', '']
# ['PS0495A1B', 'POLI SCI', '495A', 'Teaching Political Science 1', 'Eggert, P.R.', '1B', '']
# ['PS0495A1B', 'POLI SCI', '495A', 'Teaching Political Science 1', 'Eggert, P.R.', '1B', '']
# ['PS0495A1C', 'POLI SCI', '495A', 'Teaching Political Science 1', 'Eggert, P.R.', '1C', '']
# ['PS0495A1D', 'POLI SCI', '495A', 'Teaching Political Science 1', 'Eggert, P.R.', '1D', '']
# ['PS0495A1C', 'POLI SCI', '495A', 'Teaching Political Science 1', 'Eggert, P.R.', '1C', '']
# ['PS0495A1B', 'POLI SCI', '495A', 'Teaching Political Science 1', 'Eggert, P.R.', '1B', '']
# ['PS0495A1C', 'POLI SCI', '495A', 'Teaching Political Science 1', 'Eggert, P.R.', '1C', '']
# ['PS0495A1D', 'POLI SCI', '495A', 'Teaching Political Science 1', 'Eggert, P.R.', '1D', '']
# ['PS0495A1D', 'POLI SCI', '495A', 'Teaching Political Science 1', 'Eggert, P.R.', '1D', '']
# ['PS0495A1B', 'POLI SCI', '495A', 'Teaching Political Science 1', 'Eggert, P.R.', '1B', '']
# ['PS0495A1C', 'POLI SCI', '495A', 'Teaching Political Science 1', 'Eggert, P.R.', '1C', '']
# ['PS0495A1D', 'POLI SCI', '495A', 'Teaching Political Science 1', 'Eggert, P.R.', '1D', '']
# ['PS0495B1A', 'POLI SCI', '495B', 'Teaching Political Science 2', 'Eggert, P.R.', '1A', '']
# ['PS0495B1B', 'POLI SCI', '495B', 'Teaching Political Science 2', 'Eggert, P.R.', '1B', '']
# ['PS0495B1C', 'POLI SCI', '495B', 'Teaching Political Science 2', 'Eggert, P.R.', '1C', '']
# ['PS0495B1D', 'POLI SCI', '495B', 'Teaching Political Science 2', 'Eggert, P.R.', '1D', '']
# ['PS0495B1B', 'POLI SCI', '495B', 'Teaching Political Science 2', 'Eggert, P.R.', '1B', '']
# ['PS0495B1B', 'POLI SCI', '495B', 'Teaching Political Science 2', 'Eggert, P.R.', '1B', '']
# ['PS0495B1C', 'POLI SCI', '495B', 'Teaching Political Science 2', 'Eggert, P.R.', '1C', '']
# ['PS0495B1D', 'POLI SCI', '495B', 'Teaching Political Science 2', 'Eggert, P.R.', '1D', '']
# ['PS0495B1C', 'POLI SCI', '495B', 'Teaching Political Science 2', 'Eggert, P.R.', '1C', '']
# ['PS0495B1B', 'POLI SCI', '495B', 'Teaching Political Science 2', 'Eggert, P.R.', '1B', '']
# ['PS0495B1C', 'POLI SCI', '495B', 'Teaching Political Science 2', 'Eggert, P.R.', '1C', '']
# ['PS0495B1D', 'POLI SCI', '495B', 'Teaching Political Science 2', 'Eggert, P.R.', '1D', '']
# ['PS0495B1D', 'POLI SCI', '495B', 'Teaching Political Science 2', 'Eggert, P.R.', '1D', '']
# ['PS0495B1B', 'POLI SCI', '495B', 'Teaching Political Science 2', 'Eggert, P.R.', '1B', '']
# ['PS0495B1C', 'POLI SCI', '495B', 'Teaching Political Science 2', 'Eggert, P.R.', '1C', '']
# ['PS0495B1D', 'POLI SCI', '495B', 'Teaching Political Science 2', 'Eggert, P.R.', '1D', '']
# ['PS005011A', 'POLI SCI', '501', 'Cooperative Program', 'Eggert, P.R.', '1A', '']
# ['PS005011B', 'POLI SCI', '501', 'Cooperative Program', 'Eggert, P.R.', '1B', '']
# ['PS005011C', 'POLI SCI', '501', 'Cooperative Program', 'Eggert, P.R.', '1C', '']
# ['PS005011D', 'POLI SCI', '501', 'Cooperative Program', 'Eggert, P.R.', '1D', '']
# ['PS005011B', 'POLI SCI', '501', 'Cooperative Program', 'Eggert, P.R.', '1B', '']
# ['PS005011B', 'POLI SCI', '501', 'Cooperative Program', 'Eggert, P.R.', '1B', '']
# ['PS005011C', 'POLI SCI', '501', 'Cooperative Program', 'Eggert, P.R.', '1C', '']
# ['PS005011D', 'POLI SCI', '501', 'Cooperative Program', 'Eggert, P.R.', '1D', '']
# ['PS005011C', 'POLI SCI', '501', 'Cooperative Program', 'Eggert, P.R.', '1C', '']
# ['PS005011B', 'POLI SCI', '501', 'Cooperative Program', 'Eggert, P.R.', '1B', '']
# ['PS005011C', 'POLI SCI', '501', 'Cooperative Program', 'Eggert, P.R.', '1C', '']
# ['PS005011D', 'POLI SCI', '501', 'Cooperative Program', 'Eggert, P.R.', '1D', '']
# ['PS005011D', 'POLI SCI', '501', 'Cooperative Program', 'Eggert, P.R.', '1D', '']
# ['PS005011B', 'POLI SCI', '501', 'Cooperative Program', 'Eggert, P.R.', '1B', '']
# ['PS005011C', 'POLI SCI', '501', 'Cooperative Program', 'Eggert, P.R.', '1C', '']
# ['PS005011D', 'POLI SCI', '501', 'Cooperative Program', 'Eggert, P.R.', '1D', '']
# ['PS005961A', 'POLI SCI', '596', 'Directed Individual Study or Research', 'Eggert, P.R.', '1A', '']
# ['PS005961B', 'POLI SCI', '596', 'Directed Individual Study or Research', 'Eggert, P.R.', '1B', '']
# ['PS005961C', 'POLI SCI', '596', 'Directed Individual Study or Research', 'Eggert, P.R.', '1C', '']
# ['PS005961D', 'POLI SCI', '596', 'Directed Individual Study or Research', 'Eggert, P.R.', '1D', '']
# ['PS005961B', 'POLI SCI', '596', 'Directed Individual Study or Research', 'Eggert, P.R.', '1B', '']
# ['PS005961B', 'POLI SCI', '596', 'Directed Individual Study or Research', 'Eggert, P.R.', '1B', '']
# ['PS005961C', 'POLI SCI', '596', 'Directed Individual Study or Research', 'Eggert, P.R.', '1C', '']
# ['PS005961D', 'POLI SCI', '596', 'Directed Individual Study or Research', 'Eggert, P.R.', '1D', '']
# ['PS005961C', 'POLI SCI', '596', 'Directed Individual Study or Research', 'Eggert, P.R.', '1C', '']
# ['PS005961B', 'POLI SCI', '596', 'Directed Individual Study or Research', 'Eggert, P.R.', '1B', '']
# ['PS005961C', 'POLI SCI', '596', 'Directed Individual Study or Research', 'Eggert, P.R.', '1C', '']
# ['PS005961D', 'POLI SCI', '596', 'Directed Individual Study or Research', 'Eggert, P.R.', '1D', '']
# ['PS005961D', 'POLI SCI', '596', 'Directed Individual Study or Research', 'Eggert, P.R.', '1D', '']
# ['PS005961B', 'POLI SCI', '596', 'Directed Individual Study or Research', 'Eggert, P.R.', '1B', '']
# ['PS005961C', 'POLI SCI', '596', 'Directed Individual Study or Research', 'Eggert, P.R.', '1C', '']
# ['PS005961D', 'POLI SCI', '596', 'Directed Individual Study or Research', 'Eggert, P.R.', '1D', '']
# ['PS005971A', 'POLI SCI', '597', 'Preparation for PhD Qualifying Examinations', 'Eggert, P.R.', '1A', '']
# ['PS005971B', 'POLI SCI', '597', 'Preparation for PhD Qualifying Examinations', 'Eggert, P.R.', '1B', '']
# ['PS005971C', 'POLI SCI', '597', 'Preparation for PhD Qualifying Examinations', 'Eggert, P.R.', '1C', '']
# ['PS005971D', 'POLI SCI', '597', 'Preparation for PhD Qualifying Examinations', 'Eggert, P.R.', '1D', '']
# ['PS005971B', 'POLI SCI', '597', 'Preparation for PhD Qualifying Examinations', 'Eggert, P.R.', '1B', '']
# ['PS005971B', 'POLI SCI', '597', 'Preparation for PhD Qualifying Examinations', 'Eggert, P.R.', '1B', '']
# ['PS005971C', 'POLI SCI', '597', 'Preparation for PhD Qualifying Examinations', 'Eggert, P.R.', '1C', '']
# ['PS005971D', 'POLI SCI', '597', 'Preparation for PhD Qualifying Examinations', 'Eggert, P.R.', '1D', '']
# ['PS005971C', 'POLI SCI', '597', 'Preparation for PhD Qualifying Examinations', 'Eggert, P.R.', '1C', '']
# ['PS005971B', 'POLI SCI', '597', 'Preparation for PhD Qualifying Examinations', 'Eggert, P.R.', '1B', '']
# ['PS005971C', 'POLI SCI', '597', 'Preparation for PhD Qualifying Examinations', 'Eggert, P.R.', '1C', '']
# ['PS005971D', 'POLI SCI', '597', 'Preparation for PhD Qualifying Examinations', 'Eggert, P.R.', '1D', '']
# ['PS005971D', 'POLI SCI', '597', 'Preparation for PhD Qualifying Examinations', 'Eggert, P.R.', '1D', '']
# ['PS005971B', 'POLI SCI', '597', 'Preparation for PhD Qualifying Examinations', 'Eggert, P.R.', '1B', '']
# ['PS005971C', 'POLI SCI', '597', 'Preparation for PhD Qualifying Examinations', 'Eggert, P.R.', '1C', '']
# ['PS005971D', 'POLI SCI', '597', 'Preparation for PhD Qualifying Examinations', 'Eggert, P.R.', '1D', '']

# %% [markdown]
# below are failed attempts to form regular expressions that capture majors so that I can associate them with courses.

# %%
unique_first_column_values = {}  # Step 1: Create an empty dictionary

unique_rows = []  # Initialize a list to store unique rows

# Step 2: Iterate over the array of rows
for row in discussions_updated_array:
    # Step 3: Check if the value in the first column already exists in the dictionary
    if row[0] not in unique_first_column_values:
        # Step 4: If the value doesn't exist, add it to the dictionary and keep the row
        unique_first_column_values[row[0]] = True
        unique_rows.append(row)

# Step 5: After processing all rows, the dictionary will contain unique values from the first column.
# Step 6: Reconstruct the array with only the unique rows.
final_courses_array = unique_rows

# %%
for row in final_courses_array:
    print(row)
# Out:
# ['AS0001C1A', 'AERO ST', '1C', 'Heritage and Values', 'Eggert, P.R.', '1A']
# ['AS0001C1B', 'AERO ST', '1C', 'Heritage and Values', 'Eggert, P.R.', '1B']
# ['AS0001C1C', 'AERO ST', '1C', 'Heritage and Values', 'Eggert, P.R.', '1C']
# ['AS0001C1D', 'AERO ST', '1C', 'Heritage and Values', 'Eggert, P.R.', '1D']
# ['AS000191A', 'AERO ST', '19', 'Fiat Lux Freshman Seminars', 'Eggert, P.R.', '1A']
# ['AS000191B', 'AERO ST', '19', 'Fiat Lux Freshman Seminars', 'Eggert, P.R.', '1B']
# ['AS000191C', 'AERO ST', '19', 'Fiat Lux Freshman Seminars', 'Eggert, P.R.', '1C']
# ['AS000191D', 'AERO ST', '19', 'Fiat Lux Freshman Seminars', 'Eggert, P.R.', '1D']
# ['AS0020C1A', 'AERO ST', '20C', 'Team and Leadership Fundamentals', 'Eggert, P.R.', '1A']
# ['AS0020C1B', 'AERO ST', '20C', 'Team and Leadership Fundamentals', 'Eggert, P.R.', '1B']
# ['AS0020C1C', 'AERO ST', '20C', 'Team and Leadership Fundamentals', 'Eggert, P.R.', '1C']
# ['AS0020C1D', 'AERO ST', '20C', 'Team and Leadership Fundamentals', 'Eggert, P.R.', '1D']
# ['AS0130C1A', 'AERO ST', '130C', 'Air Force Leadership Studies', 'Eggert, P.R.', '1A']
# ['AS0130C1B', 'AERO ST', '130C', 'Air Force Leadership Studies', 'Eggert, P.R.', '1B']
# ['AS0130C1C', 'AERO ST', '130C', 'Air Force Leadership Studies', 'Eggert, P.R.', '1C']
# ['AS0130C1D', 'AERO ST', '130C', 'Air Force Leadership Studies', 'Eggert, P.R.', '1D']
# ['AS001971A', 'AERO ST', '197', 'Individual Studies in Aerospace Studies', 'Eggert, P.R.', '1A']
# ['AS001971B', 'AERO ST', '197', 'Individual Studies in Aerospace Studies', 'Eggert, P.R.', '1B']
# ['AS001971C', 'AERO ST', '197', 'Individual Studies in Aerospace Studies', 'Eggert, P.R.', '1C']
# ['AS001971D', 'AERO ST', '197', 'Individual Studies in Aerospace Studies', 'Eggert, P.R.', '1D']
# ['AA000011A', 'AF AMER', '1', 'Introduction to Black Studies', 'Eggert, P.R.', '1A']
# ['AA000011B', 'AF AMER', '1', 'Introduction to Black Studies', 'Eggert, P.R.', '1B']
# ['AA000011C', 'AF AMER', '1', 'Introduction to Black Studies', 'Eggert, P.R.', '1C']
# ['AA000011D', 'AF AMER', '1', 'Introduction to Black Studies', 'Eggert, P.R.', '1D']
# ['AA0002A1A', 'AF AMER', '2A', 'Africa and Middle East', 'Eggert, P.R.', '1A']
# ['AA0002A1B', 'AF AMER', '2A', 'Africa and Middle East', 'Eggert, P.R.', '1B']
# ['AA0002A1C', 'AF AMER', '2A', 'Africa and Middle East', 'Eggert, P.R.', '1C']
# ['AA0002A1D', 'AF AMER', '2A', 'Africa and Middle East', 'Eggert, P.R.', '1D']
# ['AA0002B1A', 'AF AMER', '2B', 'Race and U', 'Eggert, P.R.', '1A']
# ['AA0002B1B', 'AF AMER', '2B', 'Race and U', 'Eggert, P.R.', '1B']
# ['AA0002B1C', 'AF AMER', '2B', 'Race and U', 'Eggert, P.R.', '1C']
# ['AA0002B1D', 'AF AMER', '2B', 'Race and U', 'Eggert, P.R.', '1D']
# ['AA000M51A', 'AF AMER', 'M5', 'Social Organization of Black Communities', 'Eggert, P.R.', '1A']
# ['AA000M51B', 'AF AMER', 'M5', 'Social Organization of Black Communities', 'Eggert, P.R.', '1B']
# ['AA000M51C', 'AF AMER', 'M5', 'Social Organization of Black Communities', 'Eggert, P.R.', '1C']
# ['AA000M51D', 'AF AMER', 'M5', 'Social Organization of Black Communities', 'Eggert, P.R.', '1D']
# ['AA000061A', 'AF AMER', '6', 'Trends in Black Intellectual Thought', 'Eggert, P.R.', '1A']
# ['AA000061B', 'AF AMER', '6', 'Trends in Black Intellectual Thought', 'Eggert, P.R.', '1B']
# ['AA000061C', 'AF AMER', '6', 'Trends in Black Intellectual Thought', 'Eggert, P.R.', '1C']
# ['AA000061D', 'AF AMER', '6', 'Trends in Black Intellectual Thought', 'Eggert, P.R.', '1D']
# ['AA00M7C1A', 'AF AMER', 'M7C', 'Elementary Yoruba', 'Eggert, P.R.', '1A']
# ['AA00M7C1B', 'AF AMER', 'M7C', 'Elementary Yoruba', 'Eggert, P.R.', '1B']
# ['AA00M7C1C', 'AF AMER', 'M7C', 'Elementary Yoruba', 'Eggert, P.R.', '1C']
# ['AA00M7C1D', 'AF AMER', 'M7C', 'Elementary Yoruba', 'Eggert, P.R.', '1D']
# ['AA00M9C1A', 'AF AMER', 'M9C', 'Elementary Amharic', 'Eggert, P.R.', '1A']
# ['AA00M9C1B', 'AF AMER', 'M9C', 'Elementary Amharic', 'Eggert, P.R.', '1B']
# ['AA00M9C1C', 'AF AMER', 'M9C', 'Elementary Amharic', 'Eggert, P.R.', '1C']
# ['AA00M9C1D', 'AF AMER', 'M9C', 'Elementary Amharic', 'Eggert, P.R.', '1D']
# ['AA0M10A1A', 'AF AMER', 'M10A', 'History of Africa to 1800', 'Eggert, P.R.', '1A']
# ['AA0M10A1B', 'AF AMER', 'M10A', 'History of Africa to 1800', 'Eggert, P.R.', '1B']
# ['AA0M10A1C', 'AF AMER', 'M10A', 'History of Africa to 1800', 'Eggert, P.R.', '1C']
# ['AA0M10A1D', 'AF AMER', 'M10A', 'History of Africa to 1800', 'Eggert, P.R.', '1D']
# ['AA00M181A', 'AF AMER', 'M18', 'Leadership and Student-Initiated Retention', 'Eggert, P.R.', '1A']
# ['AA00M181B', 'AF AMER', 'M18', 'Leadership and Student-Initiated Retention', 'Eggert, P.R.', '1B']
# ['AA00M181C', 'AF AMER', 'M18', 'Leadership and Student-Initiated Retention', 'Eggert, P.R.', '1C']
# ['AA00M181D', 'AF AMER', 'M18', 'Leadership and Student-Initiated Retention', 'Eggert, P.R.', '1D']
# ['AA000191A', 'AF AMER', '19', 'Fiat Lux Freshman Seminars', 'Eggert, P.R.', '1A']
# ['AA000191B', 'AF AMER', '19', 'Fiat Lux Freshman Seminars', 'Eggert, P.R.', '1B']
# ['AA000191C', 'AF AMER', '19', 'Fiat Lux Freshman Seminars', 'Eggert, P.R.', '1C']
# ['AA000191D', 'AF AMER', '19', 'Fiat Lux Freshman Seminars', 'Eggert, P.R.', '1D']
# ['AA000891A', 'AF AMER', '89', 'Honors Seminars', 'Eggert, P.R.', '1A']
# ['AA000891B', 'AF AMER', '89', 'Honors Seminars', 'Eggert, P.R.', '1B']
# ['AA000891C', 'AF AMER', '89', 'Honors Seminars', 'Eggert, P.R.', '1C']
# ['AA000891D', 'AF AMER', '89', 'Honors Seminars', 'Eggert, P.R.', '1D']
# ['AA000991A', 'AF AMER', '99', 'Student Research Program', 'Eggert, P.R.', '1A']
# ['AA000991B', 'AF AMER', '99', 'Student Research Program', 'Eggert, P.R.', '1B']
# ['AA000991C', 'AF AMER', '99', 'Student Research Program', 'Eggert, P.R.', '1C']
# ['AA000991D', 'AF AMER', '99', 'Student Research Program', 'Eggert, P.R.', '1D']
# ['AA0M1021A', 'AF AMER', 'M102', 'Culture, Media, and Los Angeles', 'Eggert, P.R.', '1A']
# ['AA0M1021B', 'AF AMER', 'M102', 'Culture, Media, and Los Angeles', 'Eggert, P.R.', '1B']
# ['AA0M1021C', 'AF AMER', 'M102', 'Culture, Media, and Los Angeles', 'Eggert, P.R.', '1C']
# ['AA0M1021D', 'AF AMER', 'M102', 'Culture, Media, and Los Angeles', 'Eggert, P.R.', '1D']
# ['AA1800s1A', 'AF AMER', '1800s', '(4) (Same as Theater M103A', 'Eggert, P.R.', '1A']
# ['AA1800s1B', 'AF AMER', '1800s', '(4) (Same as Theater M103A', 'Eggert, P.R.', '1B']
# ['AA1800s1C', 'AF AMER', '1800s', '(4) (Same as Theater M103A', 'Eggert, P.R.', '1C']
# ['AA1800s1D', 'AF AMER', '1800s', '(4) (Same as Theater M103A', 'Eggert, P.R.', '1D']
# ['AAM104A1A', 'AF AMER', 'M104A', 'Early African American Literature', 'Eggert, P.R.', '1A']
# ['AAM104A1B', 'AF AMER', 'M104A', 'Early African American Literature', 'Eggert, P.R.', '1B']
# ['AAM104A1C', 'AF AMER', 'M104A', 'Early African American Literature', 'Eggert, P.R.', '1C']
# ['AAM104A1D', 'AF AMER', 'M104A', 'Early African American Literature', 'Eggert, P.R.', '1D']
# ['AA1960s1A', 'AF AMER', '1960s', '(5) (Same as English M104B', 'Eggert, P.R.', '1A']
# ['AA1960s1B', 'AF AMER', '1960s', '(5) (Same as English M104B', 'Eggert, P.R.', '1B']
# ['AA1960s1C', 'AF AMER', '1960s', '(5) (Same as English M104B', 'Eggert, P.R.', '1C']
# ['AA1960s1D', 'AF AMER', '1960s', '(5) (Same as English M104B', 'Eggert, P.R.', '1D']
# ['AA1970s1A', 'AF AMER', '1970s', '(5) (Same as English M104C', 'Eggert, P.R.', '1A']
# ['AA1970s1B', 'AF AMER', '1970s', '(5) (Same as English M104C', 'Eggert, P.R.', '1B']
# ['AA1970s1C', 'AF AMER', '1970s', '(5) (Same as English M104C', 'Eggert, P.R.', '1C']
# ['AA1970s1D', 'AF AMER', '1970s', '(5) (Same as English M104C', 'Eggert, P.R.', '1D']
# ['AAM104D1A', 'AF AMER', 'M104D', 'Contemporary African American Literature', 'Eggert, P.R.', '1A']
# ['AAM104D1B', 'AF AMER', 'M104D', 'Contemporary African American Literature', 'Eggert, P.R.', '1B']
# ['AAM104D1C', 'AF AMER', 'M104D', 'Contemporary African American Literature', 'Eggert, P.R.', '1C']
# ['AAM104D1D', 'AF AMER', 'M104D', 'Contemporary African American Literature', 'Eggert, P.R.', '1D']
# ['AA0105A1A', 'AF AMER', '105A', 'Ideology and Black Consciousness', 'Eggert, P.R.', '1A']
# ['AA0105A1B', 'AF AMER', '105A', 'Ideology and Black Consciousness', 'Eggert, P.R.', '1B']
# ['AA0105A1C', 'AF AMER', '105A', 'Ideology and Black Consciousness', 'Eggert, P.R.', '1C']
# ['AA0105A1D', 'AF AMER', '105A', 'Ideology and Black Consciousness', 'Eggert, P.R.', '1D']
# ['AA0106A1A', 'AF AMER', '106A', 'Africa and World', 'Eggert, P.R.', '1A']
# ['AA0106A1B', 'AF AMER', '106A', 'Africa and World', 'Eggert, P.R.', '1B']
# ['AA0106A1C', 'AF AMER', '106A', 'Africa and World', 'Eggert, P.R.', '1C']
# ['AA0106A1D', 'AF AMER', '106A', 'Africa and World', 'Eggert, P.R.', '1D']
# ['AA0M1071A', 'AF AMER', 'M107', 'Cultural History of Rap', 'Eggert, P.R.', '1A']
# ['AA0M1071B', 'AF AMER', 'M107', 'Cultural History of Rap', 'Eggert, P.R.', '1B']
# ['AA0M1071C', 'AF AMER', 'M107', 'Cultural History of Rap', 'Eggert, P.R.', '1C']
# ['AA0M1071D', 'AF AMER', 'M107', 'Cultural History of Rap', 'Eggert, P.R.', '1D']
# ['AA001081A', 'AF AMER', '108', 'Jazz and Political Imagination', 'Eggert, P.R.', '1A']
# ['AA001081B', 'AF AMER', '108', 'Jazz and Political Imagination', 'Eggert, P.R.', '1B']
# ['AA001081C', 'AF AMER', '108', 'Jazz and Political Imagination', 'Eggert, P.R.', '1C']
# ['AA001081D', 'AF AMER', '108', 'Jazz and Political Imagination', 'Eggert, P.R.', '1D']
# ['AA0M1091A', 'AF AMER', 'M109', 'Women in Jazz', 'Eggert, P.R.', '1A']
# ['AA0M1091B', 'AF AMER', 'M109', 'Women in Jazz', 'Eggert, P.R.', '1B']
# ['AA0M1091C', 'AF AMER', 'M109', 'Women in Jazz', 'Eggert, P.R.', '1C']
# ['AA0M1091D', 'AF AMER', 'M109', 'Women in Jazz', 'Eggert, P.R.', '1D']
# ['AA0110A1A', 'AF AMER', '110A', 'Race, Science, and Society', 'Eggert, P.R.', '1A']
# ['AA0110A1B', 'AF AMER', '110A', 'Race, Science, and Society', 'Eggert, P.R.', '1B']
# ['AA0110A1C', 'AF AMER', '110A', 'Race, Science, and Society', 'Eggert, P.R.', '1C']
# ['AA0110A1D', 'AF AMER', '110A', 'Race, Science, and Society', 'Eggert, P.R.', '1D']
# ['AACM110D1A', 'AF AMER', 'CM110D', 'Posthumans', 'Eggert, P.R.', '1A']
# ['AACM110D1B', 'AF AMER', 'CM110D', 'Posthumans', 'Eggert, P.R.', '1B']
# ['AACM110D1C', 'AF AMER', 'CM110D', 'Posthumans', 'Eggert, P.R.', '1C']
# ['AACM110D1D', 'AF AMER', 'CM110D', 'Posthumans', 'Eggert, P.R.', '1D']
# ['AAC210D1A', 'AF AMER', 'C210D', 'P/NP or letter grading', 'Eggert, P.R.', '1A']
# ['AAC210D1B', 'AF AMER', 'C210D', 'P/NP or letter grading', 'Eggert, P.R.', '1B']
# ['AAC210D1C', 'AF AMER', 'C210D', 'P/NP or letter grading', 'Eggert, P.R.', '1C']
# ['AAC210D1D', 'AF AMER', 'C210D', 'P/NP or letter grading', 'Eggert, P.R.', '1D']
# ['AA0M1111A', 'AF AMER', 'M111', 'Ellingtonia', 'Eggert, P.R.', '1A']
# ['AA0M1111B', 'AF AMER', 'M111', 'Ellingtonia', 'Eggert, P.R.', '1B']
# ['AA0M1111C', 'AF AMER', 'M111', 'Ellingtonia', 'Eggert, P.R.', '1C']
# ['AA0M1111D', 'AF AMER', 'M111', 'Ellingtonia', 'Eggert, P.R.', '1D']
# ['AAM114C1A', 'AF AMER', 'M114C', 'African American Political Thought', 'Eggert, P.R.', '1A']
# ['AAM114C1B', 'AF AMER', 'M114C', 'African American Political Thought', 'Eggert, P.R.', '1B']
# ['AAM114C1C', 'AF AMER', 'M114C', 'African American Political Thought', 'Eggert, P.R.', '1C']
# ['AAM114C1D', 'AF AMER', 'M114C', 'African American Political Thought', 'Eggert, P.R.', '1D']
# ['AAM116B1A', 'AF AMER', 'M116B', 'African American Musical Heritage', 'Eggert, P.R.', '1A']
# ['AAM116B1B', 'AF AMER', 'M116B', 'African American Musical Heritage', 'Eggert, P.R.', '1B']
# ['AAM116B1C', 'AF AMER', 'M116B', 'African American Musical Heritage', 'Eggert, P.R.', '1C']
# ['AAM116B1D', 'AF AMER', 'M116B', 'African American Musical Heritage', 'Eggert, P.R.', '1D']
# ['AA0M1201A', 'AF AMER', 'M120', 'Race, Inequality, and Public Policy', 'Eggert, P.R.', '1A']
# ['AA0M1201B', 'AF AMER', 'M120', 'Race, Inequality, and Public Policy', 'Eggert, P.R.', '1B']
# ['AA0M1201C', 'AF AMER', 'M120', 'Race, Inequality, and Public Policy', 'Eggert, P.R.', '1C']
# ['AA0M1201D', 'AF AMER', 'M120', 'Race, Inequality, and Public Policy', 'Eggert, P.R.', '1D']
# ['AA0M1241A', 'AF AMER', 'M124', 'Comparative Racialization and Indigeneity', 'Eggert, P.R.', '1A']
# ['AA0M1241B', 'AF AMER', 'M124', 'Comparative Racialization and Indigeneity', 'Eggert, P.R.', '1B']
# ['AA0M1241C', 'AF AMER', 'M124', 'Comparative Racialization and Indigeneity', 'Eggert, P.R.', '1C']
# ['AA0M1241D', 'AF AMER', 'M124', 'Comparative Racialization and Indigeneity', 'Eggert, P.R.', '1D']
# ['AACM135A1A', 'AF AMER', 'CM135A', 'African American Art before 1900', 'Eggert, P.R.', '1A']
# ['AACM135A1B', 'AF AMER', 'CM135A', 'African American Art before 1900', 'Eggert, P.R.', '1B']
# ['AACM135A1C', 'AF AMER', 'CM135A', 'African American Art before 1900', 'Eggert, P.R.', '1C']
# ['AACM135A1D', 'AF AMER', 'CM135A', 'African American Art before 1900', 'Eggert, P.R.', '1D']
# ['AACM235A1A', 'AF AMER', 'CM235A', 'P/NP or letter grading', 'Eggert, P.R.', '1A']
# ['AACM235A1B', 'AF AMER', 'CM235A', 'P/NP or letter grading', 'Eggert, P.R.', '1B']
# ['AACM235A1C', 'AF AMER', 'CM235A', 'P/NP or letter grading', 'Eggert, P.R.', '1C']
# ['AACM235A1D', 'AF AMER', 'CM235A', 'P/NP or letter grading', 'Eggert, P.R.', '1D']
# ['AACM135B1A', 'AF AMER', 'CM135B', 'African American Art, 1900 to 1963', 'Eggert, P.R.', '1A']
# ['AACM135B1B', 'AF AMER', 'CM135B', 'African American Art, 1900 to 1963', 'Eggert, P.R.', '1B']
# ['AACM135B1C', 'AF AMER', 'CM135B', 'African American Art, 1900 to 1963', 'Eggert, P.R.', '1C']
# ['AACM135B1D', 'AF AMER', 'CM135B', 'African American Art, 1900 to 1963', 'Eggert, P.R.', '1D']
# ['AACM235B1A', 'AF AMER', 'CM235B', 'P/NP or letter grading', 'Eggert, P.R.', '1A']
# ['AACM235B1B', 'AF AMER', 'CM235B', 'P/NP or letter grading', 'Eggert, P.R.', '1B']
# ['AACM235B1C', 'AF AMER', 'CM235B', 'P/NP or letter grading', 'Eggert, P.R.', '1C']
# ['AACM235B1D', 'AF AMER', 'CM235B', 'P/NP or letter grading', 'Eggert, P.R.', '1D']
# ['AA0M1411A', 'AF AMER', 'M141', 'African American Women’s History', 'Eggert, P.R.', '1A']
# ['AA0M1411B', 'AF AMER', 'M141', 'African American Women’s History', 'Eggert, P.R.', '1B']
# ['AA0M1411C', 'AF AMER', 'M141', 'African American Women’s History', 'Eggert, P.R.', '1C']
# ['AA0M1411D', 'AF AMER', 'M141', 'African American Women’s History', 'Eggert, P.R.', '1D']
# ['AA0M1421A', 'AF AMER', 'M142', 'Race, Gender, and Punishment', 'Eggert, P.R.', '1A']
# ['AA0M1421B', 'AF AMER', 'M142', 'Race, Gender, and Punishment', 'Eggert, P.R.', '1B']
# ['AA0M1421C', 'AF AMER', 'M142', 'Race, Gender, and Punishment', 'Eggert, P.R.', '1C']
# ['AA0M1421D', 'AF AMER', 'M142', 'Race, Gender, and Punishment', 'Eggert, P.R.', '1D']
# ['AA0M1441A', 'AF AMER', 'M144', 'Ethnic Politics: African American Politics', 'Eggert, P.R.', '1A']
# ['AA0M1441B', 'AF AMER', 'M144', 'Ethnic Politics: African American Politics', 'Eggert, P.R.', '1B']
# ['AA0M1441C', 'AF AMER', 'M144', 'Ethnic Politics: African American Politics', 'Eggert, P.R.', '1C']
# ['AA0M1441D', 'AF AMER', 'M144', 'Ethnic Politics: African American Politics', 'Eggert, P.R.', '1D']
# ['AA000401A', 'AF AMER', '40', 'Designed for juniors/seniors', 'Eggert, P.R.', '1A']
# ['AA000401B', 'AF AMER', '40', 'Designed for juniors/seniors', 'Eggert, P.R.', '1B']
# ['AA000401C', 'AF AMER', '40', 'Designed for juniors/seniors', 'Eggert, P.R.', '1C']
# ['AA000401D', 'AF AMER', '40', 'Designed for juniors/seniors', 'Eggert, P.R.', '1D']
# ['AA0M1551A', 'AF AMER', 'M155', 'Afro-Latina/o Experience(s) in U', 'Eggert, P.R.', '1A']
# ['AA0M1551B', 'AF AMER', 'M155', 'Afro-Latina/o Experience(s) in U', 'Eggert, P.R.', '1B']
# ['AA0M1551C', 'AF AMER', 'M155', 'Afro-Latina/o Experience(s) in U', 'Eggert, P.R.', '1C']
# ['AA0M1551D', 'AF AMER', 'M155', 'Afro-Latina/o Experience(s) in U', 'Eggert, P.R.', '1D']
# ['AAM158A1A', 'AF AMER', 'M158A', 'Comparative Slavery Systems', 'Eggert, P.R.', '1A']
# ['AAM158A1B', 'AF AMER', 'M158A', 'Comparative Slavery Systems', 'Eggert, P.R.', '1B']
# ['AAM158A1C', 'AF AMER', 'M158A', 'Comparative Slavery Systems', 'Eggert, P.R.', '1C']
# ['AAM158A1D', 'AF AMER', 'M158A', 'Comparative Slavery Systems', 'Eggert, P.R.', '1D']
# ['AA0M1641A', 'AF AMER', 'M164', 'Afro-American Experience in U', 'Eggert, P.R.', '1A']
# ['AA0M1641B', 'AF AMER', 'M164', 'Afro-American Experience in U', 'Eggert, P.R.', '1B']
# ['AA0M1641C', 'AF AMER', 'M164', 'Afro-American Experience in U', 'Eggert, P.R.', '1C']
# ['AA0M1641D', 'AF AMER', 'M164', 'Afro-American Experience in U', 'Eggert, P.R.', '1D']
# ['AA0M1651A', 'AF AMER', 'M165', 'Sociology of Race and Labor', 'Eggert, P.R.', '1A']
# ['AA0M1651B', 'AF AMER', 'M165', 'Sociology of Race and Labor', 'Eggert, P.R.', '1B']
# ['AA0M1651C', 'AF AMER', 'M165', 'Sociology of Race and Labor', 'Eggert, P.R.', '1C']
# ['AA0M1651D', 'AF AMER', 'M165', 'Sociology of Race and Labor', 'Eggert, P.R.', '1D']
# ['AACM1661A', 'AF AMER', 'CM166', 'Future of Work in Decarcerated California', 'Eggert, P.R.', '1A']
# ['AACM1661B', 'AF AMER', 'CM166', 'Future of Work in Decarcerated California', 'Eggert, P.R.', '1B']
# ['AACM1661C', 'AF AMER', 'CM166', 'Future of Work in Decarcerated California', 'Eggert, P.R.', '1C']
# ['AACM1661D', 'AF AMER', 'CM166', 'Future of Work in Decarcerated California', 'Eggert, P.R.', '1D']
# ['AA0C2661A', 'AF AMER', 'C266', 'P/NP or letter grading', 'Eggert, P.R.', '1A']
# ['AA0C2661B', 'AF AMER', 'C266', 'P/NP or letter grading', 'Eggert, P.R.', '1B']
# ['AA0C2661C', 'AF AMER', 'C266', 'P/NP or letter grading', 'Eggert, P.R.', '1C']
# ['AA0C2661D', 'AF AMER', 'C266', 'P/NP or letter grading', 'Eggert, P.R.', '1D']
# ['AAC266B1A', 'AF AMER', 'C266B', 'P/NP or letter grading', 'Eggert, P.R.', '1A']
# ['AAC266B1B', 'AF AMER', 'C266B', 'P/NP or letter grading', 'Eggert, P.R.', '1B']
# ['AAC266B1C', 'AF AMER', 'C266B', 'P/NP or letter grading', 'Eggert, P.R.', '1C']
# ['AAC266B1D', 'AF AMER', 'C266B', 'P/NP or letter grading', 'Eggert, P.R.', '1D']
# ['AA0M1721A', 'AF AMER', 'M172', 'Afro-American Woman in U', 'Eggert, P.R.', '1A']
# ['AA0M1721B', 'AF AMER', 'M172', 'Afro-American Woman in U', 'Eggert, P.R.', '1B']
# ['AA0M1721C', 'AF AMER', 'M172', 'Afro-American Woman in U', 'Eggert, P.R.', '1C']
# ['AA0M1721D', 'AF AMER', 'M172', 'Afro-American Woman in U', 'Eggert, P.R.', '1D']
# ['AA0M1731A', 'AF AMER', 'M173', 'Nonviolence and Social Movements', 'Eggert, P.R.', '1A']
# ['AA0M1731B', 'AF AMER', 'M173', 'Nonviolence and Social Movements', 'Eggert, P.R.', '1B']
# ['AA0M1731C', 'AF AMER', 'M173', 'Nonviolence and Social Movements', 'Eggert, P.R.', '1C']
# ['AA0M1731D', 'AF AMER', 'M173', 'Nonviolence and Social Movements', 'Eggert, P.R.', '1D']
# ['AA001751A', 'AF AMER', '175', 'Racial and Ethnic Disparities in Healthcare', 'Eggert, P.R.', '1A']
# ['AA001751B', 'AF AMER', '175', 'Racial and Ethnic Disparities in Healthcare', 'Eggert, P.R.', '1B']
# ['AA001751C', 'AF AMER', '175', 'Racial and Ethnic Disparities in Healthcare', 'Eggert, P.R.', '1C']
# ['AA001751D', 'AF AMER', '175', 'Racial and Ethnic Disparities in Healthcare', 'Eggert, P.R.', '1D']
# ['AA001761A', 'AF AMER', '176', 'Race, Racism, and Law', 'Eggert, P.R.', '1A']
# ['AA001761B', 'AF AMER', '176', 'Race, Racism, and Law', 'Eggert, P.R.', '1B']
# ['AA001761C', 'AF AMER', '176', 'Race, Racism, and Law', 'Eggert, P.R.', '1C']
# ['AA001761D', 'AF AMER', '176', 'Race, Racism, and Law', 'Eggert, P.R.', '1D']
# ['AA001771A', 'AF AMER', '177', 'African Americans in Higher Education', 'Eggert, P.R.', '1A']
# ['AA001771B', 'AF AMER', '177', 'African Americans in Higher Education', 'Eggert, P.R.', '1B']
# ['AA001771C', 'AF AMER', '177', 'African Americans in Higher Education', 'Eggert, P.R.', '1C']
# ['AA001771D', 'AF AMER', '177', 'African Americans in Higher Education', 'Eggert, P.R.', '1D']
# ['AA0M1781A', 'AF AMER', 'M178', 'Sociology of Caribbean', 'Eggert, P.R.', '1A']
# ['AA0M1781B', 'AF AMER', 'M178', 'Sociology of Caribbean', 'Eggert, P.R.', '1B']
# ['AA0M1781C', 'AF AMER', 'M178', 'Sociology of Caribbean', 'Eggert, P.R.', '1C']
# ['AA0M1781D', 'AF AMER', 'M178', 'Sociology of Caribbean', 'Eggert, P.R.', '1D']
# ['AAM179A1A', 'AF AMER', 'M179A', 'Topics in African American Literature', 'Eggert, P.R.', '1A']
# ['AAM179A1B', 'AF AMER', 'M179A', 'Topics in African American Literature', 'Eggert, P.R.', '1B']
# ['AAM179A1C', 'AF AMER', 'M179A', 'Topics in African American Literature', 'Eggert, P.R.', '1C']
# ['AAM179A1D', 'AF AMER', 'M179A', 'Topics in African American Literature', 'Eggert, P.R.', '1D']
# ['AA0188A1A', 'AF AMER', '188A', 'Special Courses in African American Studies', 'Eggert, P.R.', '1A']
# ['AA0188A1B', 'AF AMER', '188A', 'Special Courses in African American Studies', 'Eggert, P.R.', '1B']
# ['AA0188A1C', 'AF AMER', '188A', 'Special Courses in African American Studies', 'Eggert, P.R.', '1C']
# ['AA0188A1D', 'AF AMER', '188A', 'Special Courses in African American Studies', 'Eggert, P.R.', '1D']
# ['AA0188B1A', 'AF AMER', '188B', 'Race and Public Policy', 'Eggert, P.R.', '1A']
# ['AA0188B1B', 'AF AMER', '188B', 'Race and Public Policy', 'Eggert, P.R.', '1B']
# ['AA0188B1C', 'AF AMER', '188B', 'Race and Public Policy', 'Eggert, P.R.', '1C']
# ['AA0188B1D', 'AF AMER', '188B', 'Race and Public Policy', 'Eggert, P.R.', '1D']
# ['AA0101E1A', 'AF AMER', '101E', 'Limited to junior/senior USIE facilitators', 'Eggert, P.R.', '1A']
# ['AA0101E1B', 'AF AMER', '101E', 'Limited to junior/senior USIE facilitators', 'Eggert, P.R.', '1B']
# ['AA0101E1C', 'AF AMER', '101E', 'Limited to junior/senior USIE facilitators', 'Eggert, P.R.', '1C']
# ['AA0101E1D', 'AF AMER', '101E', 'Limited to junior/senior USIE facilitators', 'Eggert, P.R.', '1D']
# ['AA001891A', 'AF AMER', '189', 'Advanced Honors Seminars', 'Eggert, P.R.', '1A']
# ['AA001891B', 'AF AMER', '189', 'Advanced Honors Seminars', 'Eggert, P.R.', '1B']
# ['AA001891C', 'AF AMER', '189', 'Advanced Honors Seminars', 'Eggert, P.R.', '1C']
# ['AA001891D', 'AF AMER', '189', 'Advanced Honors Seminars', 'Eggert, P.R.', '1D']
# ['AA0C2911A', 'AF AMER', 'C291', 'Letter grading', 'Eggert, P.R.', '1A']
# ['AA0C2911B', 'AF AMER', 'C291', 'Letter grading', 'Eggert, P.R.', '1B']
# ['AA0C2911C', 'AF AMER', 'C291', 'Letter grading', 'Eggert, P.R.', '1C']
# ['AA0C2911D', 'AF AMER', 'C291', 'Letter grading', 'Eggert, P.R.', '1D']
# ['AA001971A', 'AF AMER', '197', 'Individual Studies in Afro-American Studies', 'Eggert, P.R.', '1A']
# ['AA001971B', 'AF AMER', '197', 'Individual Studies in Afro-American Studies', 'Eggert, P.R.', '1B']
# ['AA001971C', 'AF AMER', '197', 'Individual Studies in Afro-American Studies', 'Eggert, P.R.', '1C']
# ['AA001971D', 'AF AMER', '197', 'Individual Studies in Afro-American Studies', 'Eggert, P.R.', '1D']
# ['AA001981A', 'AF AMER', '198', 'Honors Research in Afro-American Studies', 'Eggert, P.R.', '1A']
# ['AA001981B', 'AF AMER', '198', 'Honors Research in Afro-American Studies', 'Eggert, P.R.', '1B']
# ['AA001981C', 'AF AMER', '198', 'Honors Research in Afro-American Studies', 'Eggert, P.R.', '1C']
# ['AA001981D', 'AF AMER', '198', 'Honors Research in Afro-American Studies', 'Eggert, P.R.', '1D']
# ['AAM200A1A', 'AF AMER', 'M200A', 'Advanced Historiography: Afro-American', 'Eggert, P.R.', '1A']
# ['AAM200A1B', 'AF AMER', 'M200A', 'Advanced Historiography: Afro-American', 'Eggert, P.R.', '1B']
# ['AAM200A1C', 'AF AMER', 'M200A', 'Advanced Historiography: Afro-American', 'Eggert, P.R.', '1C']
# ['AAM200A1D', 'AF AMER', 'M200A', 'Advanced Historiography: Afro-American', 'Eggert, P.R.', '1D']
# ['AAM200B1A', 'AF AMER', 'M200B', 'Political Economy of Race', 'Eggert, P.R.', '1A']
# ['AAM200B1B', 'AF AMER', 'M200B', 'Political Economy of Race', 'Eggert, P.R.', '1B']
# ['AAM200B1C', 'AF AMER', 'M200B', 'Political Economy of Race', 'Eggert, P.R.', '1C']
# ['AAM200B1D', 'AF AMER', 'M200B', 'Political Economy of Race', 'Eggert, P.R.', '1D']
# ['AAM200C1A', 'AF AMER', 'M200C', 'Black Families and Relationships', 'Eggert, P.R.', '1A']
# ['AAM200C1B', 'AF AMER', 'M200C', 'Black Families and Relationships', 'Eggert, P.R.', '1B']
# ['AAM200C1C', 'AF AMER', 'M200C', 'Black Families and Relationships', 'Eggert, P.R.', '1C']
# ['AAM200C1D', 'AF AMER', 'M200C', 'Black Families and Relationships', 'Eggert, P.R.', '1D']
# ['AA0200D1A', 'AF AMER', '200D', 'African American Women’s History', 'Eggert, P.R.', '1A']
# ['AA0200D1B', 'AF AMER', '200D', 'African American Women’s History', 'Eggert, P.R.', '1B']
# ['AA0200D1C', 'AF AMER', '200D', 'African American Women’s History', 'Eggert, P.R.', '1C']
# ['AA0200D1D', 'AF AMER', '200D', 'African American Women’s History', 'Eggert, P.R.', '1D']
# ['AAM200E1A', 'AF AMER', 'M200E', 'Studies in Afro-American Literature', 'Eggert, P.R.', '1A']
# ['AAM200E1B', 'AF AMER', 'M200E', 'Studies in Afro-American Literature', 'Eggert, P.R.', '1B']
# ['AAM200E1C', 'AF AMER', 'M200E', 'Studies in Afro-American Literature', 'Eggert, P.R.', '1C']
# ['AAM200E1D', 'AF AMER', 'M200E', 'Studies in Afro-American Literature', 'Eggert, P.R.', '1D']
# ['AA0201C1A', 'AF AMER', '201C', 'Research Proposal Writing Seminar', 'Eggert, P.R.', '1A']
# ['AA0201C1B', 'AF AMER', '201C', 'Research Proposal Writing Seminar', 'Eggert, P.R.', '1B']
# ['AA0201C1C', 'AF AMER', '201C', 'Research Proposal Writing Seminar', 'Eggert, P.R.', '1C']
# ['AA0201C1D', 'AF AMER', '201C', 'Research Proposal Writing Seminar', 'Eggert, P.R.', '1D']
# ['AA0M2021A', 'AF AMER', 'M202', 'Critical Theory of African Diaspora', 'Eggert, P.R.', '1A']
# ['AA0M2021B', 'AF AMER', 'M202', 'Critical Theory of African Diaspora', 'Eggert, P.R.', '1B']
# ['AA0M2021C', 'AF AMER', 'M202', 'Critical Theory of African Diaspora', 'Eggert, P.R.', '1C']
# ['AA0M2021D', 'AF AMER', 'M202', 'Critical Theory of African Diaspora', 'Eggert, P.R.', '1D']
# ['AA019741A', 'AF AMER', '1974', '(4) Seminar, three hours', 'Eggert, P.R.', '1A']
# ['AA019741B', 'AF AMER', '1974', '(4) Seminar, three hours', 'Eggert, P.R.', '1B']
# ['AA019741C', 'AF AMER', '1974', '(4) Seminar, three hours', 'Eggert, P.R.', '1C']
# ['AA019741D', 'AF AMER', '1974', '(4) Seminar, three hours', 'Eggert, P.R.', '1D']
# ['AA0203B1A', 'AF AMER', '203B', 'Readings in African Political Economy', 'Eggert, P.R.', '1A']
# ['AA0203B1B', 'AF AMER', '203B', 'Readings in African Political Economy', 'Eggert, P.R.', '1B']
# ['AA0203B1C', 'AF AMER', '203B', 'Readings in African Political Economy', 'Eggert, P.R.', '1C']
# ['AA0203B1D', 'AF AMER', '203B', 'Readings in African Political Economy', 'Eggert, P.R.', '1D']
# ['AA1990s1A', 'AF AMER', '1990s', 'S/U or letter grading', 'Eggert, P.R.', '1A']
# ['AA1990s1B', 'AF AMER', '1990s', 'S/U or letter grading', 'Eggert, P.R.', '1B']
# ['AA1990s1C', 'AF AMER', '1990s', 'S/U or letter grading', 'Eggert, P.R.', '1C']
# ['AA1990s1D', 'AF AMER', '1990s', 'S/U or letter grading', 'Eggert, P.R.', '1D']
# ['AACM1101A', 'AF AMER', 'CM110', 'Letter grading', 'Eggert, P.R.', '1A']
# ['AACM1101B', 'AF AMER', 'CM110', 'Letter grading', 'Eggert, P.R.', '1B']
# ['AACM1101C', 'AF AMER', 'CM110', 'Letter grading', 'Eggert, P.R.', '1C']
# ['AACM1101D', 'AF AMER', 'CM110', 'Letter grading', 'Eggert, P.R.', '1D']
# ['AA0M2111A', 'AF AMER', 'M211', 'Seminar: African American Music', 'Eggert, P.R.', '1A']
# ['AA0M2111B', 'AF AMER', 'M211', 'Seminar: African American Music', 'Eggert, P.R.', '1B']
# ['AA0M2111C', 'AF AMER', 'M211', 'Seminar: African American Music', 'Eggert, P.R.', '1C']
# ['AA0M2111D', 'AF AMER', 'M211', 'Seminar: African American Music', 'Eggert, P.R.', '1D']
# ['AA002411A', 'AF AMER', '241', 'Special Topics in Afro-American Studies', 'Eggert, P.R.', '1A']
# ['AA002411B', 'AF AMER', '241', 'Special Topics in Afro-American Studies', 'Eggert, P.R.', '1B']
# ['AA002411C', 'AF AMER', '241', 'Special Topics in Afro-American Studies', 'Eggert, P.R.', '1C']
# ['AA002411D', 'AF AMER', '241', 'Special Topics in Afro-American Studies', 'Eggert, P.R.', '1D']
# ['AA0M2561A', 'AF AMER', 'M256', 'Topics in African American Art', 'Eggert, P.R.', '1A']
# ['AA0M2561B', 'AF AMER', 'M256', 'Topics in African American Art', 'Eggert, P.R.', '1B']
# ['AA0M2561C', 'AF AMER', 'M256', 'Topics in African American Art', 'Eggert, P.R.', '1C']
# ['AA0M2561D', 'AF AMER', 'M256', 'Topics in African American Art', 'Eggert, P.R.', '1D']
# ['AACM166B1A', 'AF AMER', 'CM166B', 'S/U or letter grading', 'Eggert, P.R.', '1A']
# ['AACM166B1B', 'AF AMER', 'CM166B', 'S/U or letter grading', 'Eggert, P.R.', '1B']
# ['AACM166B1C', 'AF AMER', 'CM166B', 'S/U or letter grading', 'Eggert, P.R.', '1C']
# ['AACM166B1D', 'AF AMER', 'CM166B', 'S/U or letter grading', 'Eggert, P.R.', '1D']
# ['AA0270A1A', 'AF AMER', '270A', 'Survey of Afro-American Research', 'Eggert, P.R.', '1A']
# ['AA0270A1B', 'AF AMER', '270A', 'Survey of Afro-American Research', 'Eggert, P.R.', '1B']
# ['AA0270A1C', 'AF AMER', '270A', 'Survey of Afro-American Research', 'Eggert, P.R.', '1C']
# ['AA0270A1D', 'AF AMER', '270A', 'Survey of Afro-American Research', 'Eggert, P.R.', '1D']
# ['AA0C1911A', 'AF AMER', 'C191', 'Letter grading', 'Eggert, P.R.', '1A']
# ['AA0C1911B', 'AF AMER', 'C191', 'Letter grading', 'Eggert, P.R.', '1B']
# ['AA0C1911C', 'AF AMER', 'C191', 'Letter grading', 'Eggert, P.R.', '1C']
# ['AA0C1911D', 'AF AMER', 'C191', 'Letter grading', 'Eggert, P.R.', '1D']
# ['AA003751A', 'AF AMER', '375', 'Teaching Apprentice Practicum', 'Eggert, P.R.', '1A']
# ['AA003751B', 'AF AMER', '375', 'Teaching Apprentice Practicum', 'Eggert, P.R.', '1B']
# ['AA003751C', 'AF AMER', '375', 'Teaching Apprentice Practicum', 'Eggert, P.R.', '1C']
# ['AA003751D', 'AF AMER', '375', 'Teaching Apprentice Practicum', 'Eggert, P.R.', '1D']
# ['AA005961A', 'AF AMER', '596', 'Directed Readings and Tutorials', 'Eggert, P.R.', '1A']
# ['AA005961B', 'AF AMER', '596', 'Directed Readings and Tutorials', 'Eggert, P.R.', '1B']
# ['AA005961C', 'AF AMER', '596', 'Directed Readings and Tutorials', 'Eggert, P.R.', '1C']
# ['AA005961D', 'AF AMER', '596', 'Directed Readings and Tutorials', 'Eggert, P.R.', '1D']
# ['AA005981A', 'AF AMER', '598', 'Research for and Preparation of MA Thesis', 'Eggert, P.R.', '1A']
# ['AA005981B', 'AF AMER', '598', 'Research for and Preparation of MA Thesis', 'Eggert, P.R.', '1B']
# ['AA005981C', 'AF AMER', '598', 'Research for and Preparation of MA Thesis', 'Eggert, P.R.', '1C']
# ['AA005981D', 'AF AMER', '598', 'Research for and Preparation of MA Thesis', 'Eggert, P.R.', '1D']
# ['AA0201A1A', 'AF AMER', '201A', 'Africa and Disciplines', 'Eggert, P.R.', '1A']
# ['AA0201A1B', 'AF AMER', '201A', 'Africa and Disciplines', 'Eggert, P.R.', '1B']
# ['AA0201A1C', 'AF AMER', '201A', 'Africa and Disciplines', 'Eggert, P.R.', '1C']
# ['AA0201A1D', 'AF AMER', '201A', 'Africa and Disciplines', 'Eggert, P.R.', '1D']
# ['AA0201B1A', 'AF AMER', '201B', 'Africa and Professions', 'Eggert, P.R.', '1A']
# ['AA0201B1B', 'AF AMER', '201B', 'Africa and Professions', 'Eggert, P.R.', '1B']
# ['AA0201B1C', 'AF AMER', '201B', 'Africa and Professions', 'Eggert, P.R.', '1C']
# ['AA0201B1D', 'AF AMER', '201B', 'Africa and Professions', 'Eggert, P.R.', '1D']
# ['AA002961A', 'AF AMER', '296', 'Africanist Working Group', 'Eggert, P.R.', '1A']
# ['AA002961B', 'AF AMER', '296', 'Africanist Working Group', 'Eggert, P.R.', '1B']
# ['AA002961C', 'AF AMER', '296', 'Africanist Working Group', 'Eggert, P.R.', '1C']
# ['AA002961D', 'AF AMER', '296', 'Africanist Working Group', 'Eggert, P.R.', '1D']
# ['AA00M101A', 'AF AMER', 'M10', 'Introduction to American Indian Studies', 'Eggert, P.R.', '1A']
# ['AA00M101B', 'AF AMER', 'M10', 'Introduction to American Indian Studies', 'Eggert, P.R.', '1B']
# ['AA00M101C', 'AF AMER', 'M10', 'Introduction to American Indian Studies', 'Eggert, P.R.', '1C']
# ['AA00M101D', 'AF AMER', 'M10', 'Introduction to American Indian Studies', 'Eggert, P.R.', '1D']
# ['CS000011A', 'COM SCI', '1', 'Freshman Computer Science Seminar', 'Eggert, P.R.', '1A']
# ['CS000011B', 'COM SCI', '1', 'Freshman Computer Science Seminar', 'Eggert, P.R.', '1B']
# ['CS000011C', 'COM SCI', '1', 'Freshman Computer Science Seminar', 'Eggert, P.R.', '1C']
# ['CS000011D', 'COM SCI', '1', 'Freshman Computer Science Seminar', 'Eggert, P.R.', '1D']
# ['CS000191A', 'COM SCI', '19', 'Fiat Lux Freshman Seminars', 'Eggert, P.R.', '1A']
# ['CS000191B', 'COM SCI', '19', 'Fiat Lux Freshman Seminars', 'Eggert, P.R.', '1B']
# ['CS000191C', 'COM SCI', '19', 'Fiat Lux Freshman Seminars', 'Eggert, P.R.', '1C']
# ['CS000191D', 'COM SCI', '19', 'Fiat Lux Freshman Seminars', 'Eggert, P.R.', '1D']
# ['CS000301A', 'COM SCI', '30', 'Principles and Practices of Computing', 'Eggert, P.R.', '1A']
# ['CS000301B', 'COM SCI', '30', 'Principles and Practices of Computing', 'Eggert, P.R.', '1B']
# ['CS000301C', 'COM SCI', '30', 'Principles and Practices of Computing', 'Eggert, P.R.', '1C']
# ['CS000301D', 'COM SCI', '30', 'Principles and Practices of Computing', 'Eggert, P.R.', '1D']
# ['CS000311A', 'COM SCI', '31', 'Introduction to Computer Science I', 'Eggert, P.R.', '1A']
# ['CS000311B', 'COM SCI', '31', 'Introduction to Computer Science I', 'Eggert, P.R.', '1B']
# ['CS000311C', 'COM SCI', '31', 'Introduction to Computer Science I', 'Eggert, P.R.', '1C']
# ['CS000311D', 'COM SCI', '31', 'Introduction to Computer Science I', 'Eggert, P.R.', '1D']
# ['CS000321A', 'COM SCI', '32', 'Introduction to Computer Science II', 'Eggert, P.R.', '1A']
# ['CS000321B', 'COM SCI', '32', 'Introduction to Computer Science II', 'Eggert, P.R.', '1B']
# ['CS000321C', 'COM SCI', '32', 'Introduction to Computer Science II', 'Eggert, P.R.', '1C']
# ['CS000321D', 'COM SCI', '32', 'Introduction to Computer Science II', 'Eggert, P.R.', '1D']
# ['CS000331A', 'COM SCI', '33', 'Introduction to Computer Organization', 'Eggert, P.R.', '1A']
# ['CS000331B', 'COM SCI', '33', 'Introduction to Computer Organization', 'Eggert, P.R.', '1B']
# ['CS000331C', 'COM SCI', '33', 'Introduction to Computer Organization', 'Eggert, P.R.', '1C']
# ['CS000331D', 'COM SCI', '33', 'Introduction to Computer Organization', 'Eggert, P.R.', '1D']
# ['CS0035L1A', 'COM SCI', '35L', 'Software Construction', 'Eggert, P.R.', '1A']
# ['CS0035L1B', 'COM SCI', '35L', 'Software Construction', 'Eggert, P.R.', '1B']
# ['CS0035L1C', 'COM SCI', '35L', 'Software Construction', 'Eggert, P.R.', '1C']
# ['CS0035L1D', 'COM SCI', '35L', 'Software Construction', 'Eggert, P.R.', '1D']
# ['CS0M51A1A', 'COM SCI', 'M51A', 'Logic Design of Digital Systems', 'Eggert, P.R.', '1A']
# ['CS0M51A1B', 'COM SCI', 'M51A', 'Logic Design of Digital Systems', 'Eggert, P.R.', '1B']
# ['CS0M51A1C', 'COM SCI', 'M51A', 'Logic Design of Digital Systems', 'Eggert, P.R.', '1C']
# ['CS0M51A1D', 'COM SCI', 'M51A', 'Logic Design of Digital Systems', 'Eggert, P.R.', '1D']
# ['CS000971A', 'COM SCI', '97', 'Variable Topics in Computer Science', 'Eggert, P.R.', '1A']
# ['CS000971B', 'COM SCI', '97', 'Variable Topics in Computer Science', 'Eggert, P.R.', '1B']
# ['CS000971C', 'COM SCI', '97', 'Variable Topics in Computer Science', 'Eggert, P.R.', '1C']
# ['CS000971D', 'COM SCI', '97', 'Variable Topics in Computer Science', 'Eggert, P.R.', '1D']
# ['CS000991A', 'COM SCI', '99', 'Student Research Program', 'Eggert, P.R.', '1A']
# ['CS000991B', 'COM SCI', '99', 'Student Research Program', 'Eggert, P.R.', '1B']
# ['CS000991C', 'COM SCI', '99', 'Student Research Program', 'Eggert, P.R.', '1C']
# ['CS000991D', 'COM SCI', '99', 'Student Research Program', 'Eggert, P.R.', '1D']
# ['CS001111A', 'COM SCI', '111', 'Operating Systems Principles', 'Eggert, P.R.', '1A']
# ['CS001111B', 'COM SCI', '111', 'Operating Systems Principles', 'Eggert, P.R.', '1B']
# ['CS001111C', 'COM SCI', '111', 'Operating Systems Principles', 'Eggert, P.R.', '1C']
# ['CS001111D', 'COM SCI', '111', 'Operating Systems Principles', 'Eggert, P.R.', '1D']
# ['CS001121A', 'COM SCI', '112', 'Modeling Uncertainty in Information Systems', 'Eggert, P.R.', '1A']
# ['CS001121B', 'COM SCI', '112', 'Modeling Uncertainty in Information Systems', 'Eggert, P.R.', '1B']
# ['CS001121C', 'COM SCI', '112', 'Modeling Uncertainty in Information Systems', 'Eggert, P.R.', '1C']
# ['CS001121D', 'COM SCI', '112', 'Modeling Uncertainty in Information Systems', 'Eggert, P.R.', '1D']
# ['CS0100A1A', 'COM SCI', '100A', 'Designed for juniors/seniors', 'Eggert, P.R.', '1A']
# ['CS0100A1B', 'COM SCI', '100A', 'Designed for juniors/seniors', 'Eggert, P.R.', '1B']
# ['CS0100A1C', 'COM SCI', '100A', 'Designed for juniors/seniors', 'Eggert, P.R.', '1C']
# ['CS0100A1D', 'COM SCI', '100A', 'Designed for juniors/seniors', 'Eggert, P.R.', '1D']
# ['CS001171A', 'COM SCI', '117', 'Computer Networks: Physical Layer', 'Eggert, P.R.', '1A']
# ['CS001171B', 'COM SCI', '117', 'Computer Networks: Physical Layer', 'Eggert, P.R.', '1B']
# ['CS001171C', 'COM SCI', '117', 'Computer Networks: Physical Layer', 'Eggert, P.R.', '1C']
# ['CS001171D', 'COM SCI', '117', 'Computer Networks: Physical Layer', 'Eggert, P.R.', '1D']
# ['CS001181A', 'COM SCI', '118', 'Computer Network Fundamentals', 'Eggert, P.R.', '1A']
# ['CS001181B', 'COM SCI', '118', 'Computer Network Fundamentals', 'Eggert, P.R.', '1B']
# ['CS001181C', 'COM SCI', '118', 'Computer Network Fundamentals', 'Eggert, P.R.', '1C']
# ['CS001181D', 'COM SCI', '118', 'Computer Network Fundamentals', 'Eggert, P.R.', '1D']
# ['CSCM1211A', 'COM SCI', 'CM121', 'Introduction to Bioinformatics', 'Eggert, P.R.', '1A']
# ['CSCM1211B', 'COM SCI', 'CM121', 'Introduction to Bioinformatics', 'Eggert, P.R.', '1B']
# ['CSCM1211C', 'COM SCI', 'CM121', 'Introduction to Bioinformatics', 'Eggert, P.R.', '1C']
# ['CSCM1211D', 'COM SCI', 'CM121', 'Introduction to Bioinformatics', 'Eggert, P.R.', '1D']
# ['CS0C1221A', 'COM SCI', 'C122', 'Algorithms in Computational Genomics', 'Eggert, P.R.', '1A']
# ['CS0C1221B', 'COM SCI', 'C122', 'Algorithms in Computational Genomics', 'Eggert, P.R.', '1B']
# ['CS0C1221C', 'COM SCI', 'C122', 'Algorithms in Computational Genomics', 'Eggert, P.R.', '1C']
# ['CS0C1221D', 'COM SCI', 'C122', 'Algorithms in Computational Genomics', 'Eggert, P.R.', '1D']
# ['CS0C2221A', 'COM SCI', 'C222', 'Letter grading', 'Eggert, P.R.', '1A']
# ['CS0C2221B', 'COM SCI', 'C222', 'Letter grading', 'Eggert, P.R.', '1B']
# ['CS0C2221C', 'COM SCI', 'C222', 'Letter grading', 'Eggert, P.R.', '1C']
# ['CS0C2221D', 'COM SCI', 'C222', 'Letter grading', 'Eggert, P.R.', '1D']
# ['CSCM1241A', 'COM SCI', 'CM124', 'Machine Learning Applications in Genetics', 'Eggert, P.R.', '1A']
# ['CSCM1241B', 'COM SCI', 'CM124', 'Machine Learning Applications in Genetics', 'Eggert, P.R.', '1B']
# ['CSCM1241C', 'COM SCI', 'CM124', 'Machine Learning Applications in Genetics', 'Eggert, P.R.', '1C']
# ['CSCM1241D', 'COM SCI', 'CM124', 'Machine Learning Applications in Genetics', 'Eggert, P.R.', '1D']
# ['CS001301A', 'COM SCI', '130', 'Software Engineering', 'Eggert, P.R.', '1A']
# ['CS001301B', 'COM SCI', '130', 'Software Engineering', 'Eggert, P.R.', '1B']
# ['CS001301C', 'COM SCI', '130', 'Software Engineering', 'Eggert, P.R.', '1C']
# ['CS001301D', 'COM SCI', '130', 'Software Engineering', 'Eggert, P.R.', '1D']
# ['CS001311A', 'COM SCI', '131', 'Programming Languages', 'Eggert, P.R.', '1A']
# ['CS001311B', 'COM SCI', '131', 'Programming Languages', 'Eggert, P.R.', '1B']
# ['CS001311C', 'COM SCI', '131', 'Programming Languages', 'Eggert, P.R.', '1C']
# ['CS001311D', 'COM SCI', '131', 'Programming Languages', 'Eggert, P.R.', '1D']
# ['CS001321A', 'COM SCI', '132', 'Compiler Construction', 'Eggert, P.R.', '1A']
# ['CS001321B', 'COM SCI', '132', 'Compiler Construction', 'Eggert, P.R.', '1B']
# ['CS001321C', 'COM SCI', '132', 'Compiler Construction', 'Eggert, P.R.', '1C']
# ['CS001321D', 'COM SCI', '132', 'Compiler Construction', 'Eggert, P.R.', '1D']
# ['CS001331A', 'COM SCI', '133', 'Parallel and Distributed Computing', 'Eggert, P.R.', '1A']
# ['CS001331B', 'COM SCI', '133', 'Parallel and Distributed Computing', 'Eggert, P.R.', '1B']
# ['CS001331C', 'COM SCI', '133', 'Parallel and Distributed Computing', 'Eggert, P.R.', '1C']
# ['CS001331D', 'COM SCI', '133', 'Parallel and Distributed Computing', 'Eggert, P.R.', '1D']
# ['CS001341A', 'COM SCI', '134', 'Distributed Systems', 'Eggert, P.R.', '1A']
# ['CS001341B', 'COM SCI', '134', 'Distributed Systems', 'Eggert, P.R.', '1B']
# ['CS001341C', 'COM SCI', '134', 'Distributed Systems', 'Eggert, P.R.', '1C']
# ['CS001341D', 'COM SCI', '134', 'Distributed Systems', 'Eggert, P.R.', '1D']
# ['CS001361A', 'COM SCI', '136', 'Introduction to Computer Security', 'Eggert, P.R.', '1A']
# ['CS001361B', 'COM SCI', '136', 'Introduction to Computer Security', 'Eggert, P.R.', '1B']
# ['CS001361C', 'COM SCI', '136', 'Introduction to Computer Security', 'Eggert, P.R.', '1C']
# ['CS001361D', 'COM SCI', '136', 'Introduction to Computer Security', 'Eggert, P.R.', '1D']
# ['CSC137A1A', 'COM SCI', 'C137A', 'Prototyping Programming Languages', 'Eggert, P.R.', '1A']
# ['CSC137A1B', 'COM SCI', 'C137A', 'Prototyping Programming Languages', 'Eggert, P.R.', '1B']
# ['CSC137A1C', 'COM SCI', 'C137A', 'Prototyping Programming Languages', 'Eggert, P.R.', '1C']
# ['CSC137A1D', 'COM SCI', 'C137A', 'Prototyping Programming Languages', 'Eggert, P.R.', '1D']
# ['CSC237A1A', 'COM SCI', 'C237A', 'Letter grading', 'Eggert, P.R.', '1A']
# ['CSC237A1B', 'COM SCI', 'C237A', 'Letter grading', 'Eggert, P.R.', '1B']
# ['CSC237A1C', 'COM SCI', 'C237A', 'Letter grading', 'Eggert, P.R.', '1C']
# ['CSC237A1D', 'COM SCI', 'C237A', 'Letter grading', 'Eggert, P.R.', '1D']
# ['CSC137B1A', 'COM SCI', 'C137B', 'Programming Language Design', 'Eggert, P.R.', '1A']
# ['CSC137B1B', 'COM SCI', 'C137B', 'Programming Language Design', 'Eggert, P.R.', '1B']
# ['CSC137B1C', 'COM SCI', 'C137B', 'Programming Language Design', 'Eggert, P.R.', '1C']
# ['CSC137B1D', 'COM SCI', 'C137B', 'Programming Language Design', 'Eggert, P.R.', '1D']
# ['CS001431A', 'COM SCI', '143', 'Data Management Systems', 'Eggert, P.R.', '1A']
# ['CS001431B', 'COM SCI', '143', 'Data Management Systems', 'Eggert, P.R.', '1B']
# ['CS001431C', 'COM SCI', '143', 'Data Management Systems', 'Eggert, P.R.', '1C']
# ['CS001431D', 'COM SCI', '143', 'Data Management Systems', 'Eggert, P.R.', '1D']
# ['CS001441A', 'COM SCI', '144', 'Web Applications', 'Eggert, P.R.', '1A']
# ['CS001441B', 'COM SCI', '144', 'Web Applications', 'Eggert, P.R.', '1B']
# ['CS001441C', 'COM SCI', '144', 'Web Applications', 'Eggert, P.R.', '1C']
# ['CS001441D', 'COM SCI', '144', 'Web Applications', 'Eggert, P.R.', '1D']
# ['CS001451A', 'COM SCI', '145', 'Introduction to Data Mining', 'Eggert, P.R.', '1A']
# ['CS001451B', 'COM SCI', '145', 'Introduction to Data Mining', 'Eggert, P.R.', '1B']
# ['CS001451C', 'COM SCI', '145', 'Introduction to Data Mining', 'Eggert, P.R.', '1C']
# ['CS001451D', 'COM SCI', '145', 'Introduction to Data Mining', 'Eggert, P.R.', '1D']
# ['CS0M1461A', 'COM SCI', 'M146', 'Introduction to Machine Learning', 'Eggert, P.R.', '1A']
# ['CS0M1461B', 'COM SCI', 'M146', 'Introduction to Machine Learning', 'Eggert, P.R.', '1B']
# ['CS0M1461C', 'COM SCI', 'M146', 'Introduction to Machine Learning', 'Eggert, P.R.', '1C']
# ['CS0M1461D', 'COM SCI', 'M146', 'Introduction to Machine Learning', 'Eggert, P.R.', '1D']
# ['CS0033A1A', 'COM SCI', '33A', 'Introduction to breadth of data science', 'Eggert, P.R.', '1A']
# ['CS0033A1B', 'COM SCI', '33A', 'Introduction to breadth of data science', 'Eggert, P.R.', '1B']
# ['CS0033A1C', 'COM SCI', '33A', 'Introduction to breadth of data science', 'Eggert, P.R.', '1C']
# ['CS0033A1D', 'COM SCI', '33A', 'Introduction to breadth of data science', 'Eggert, P.R.', '1D']
# ['CS0M1481A', 'COM SCI', 'M148', 'Introduction to Data Science', 'Eggert, P.R.', '1A']
# ['CS0M1481B', 'COM SCI', 'M148', 'Introduction to Data Science', 'Eggert, P.R.', '1B']
# ['CS0M1481C', 'COM SCI', 'M148', 'Introduction to Data Science', 'Eggert, P.R.', '1C']
# ['CS0M1481D', 'COM SCI', 'M148', 'Introduction to Data Science', 'Eggert, P.R.', '1D']
# ['CSM151B1A', 'COM SCI', 'M151B', 'Computer Systems Architecture', 'Eggert, P.R.', '1A']
# ['CSM151B1B', 'COM SCI', 'M151B', 'Computer Systems Architecture', 'Eggert, P.R.', '1B']
# ['CSM151B1C', 'COM SCI', 'M151B', 'Computer Systems Architecture', 'Eggert, P.R.', '1C']
# ['CSM151B1D', 'COM SCI', 'M151B', 'Computer Systems Architecture', 'Eggert, P.R.', '1D']
# ['CSM152A1A', 'COM SCI', 'M152A', 'Introductory Digital Design Laboratory', 'Eggert, P.R.', '1A']
# ['CSM152A1B', 'COM SCI', 'M152A', 'Introductory Digital Design Laboratory', 'Eggert, P.R.', '1B']
# ['CSM152A1C', 'COM SCI', 'M152A', 'Introductory Digital Design Laboratory', 'Eggert, P.R.', '1C']
# ['CSM152A1D', 'COM SCI', 'M152A', 'Introductory Digital Design Laboratory', 'Eggert, P.R.', '1D']
# ['CS0152B1A', 'COM SCI', '152B', 'Digital Design Project Laboratory', 'Eggert, P.R.', '1A']
# ['CS0152B1B', 'COM SCI', '152B', 'Digital Design Project Laboratory', 'Eggert, P.R.', '1B']
# ['CS0152B1C', 'COM SCI', '152B', 'Digital Design Project Laboratory', 'Eggert, P.R.', '1C']
# ['CS0152B1D', 'COM SCI', '152B', 'Digital Design Project Laboratory', 'Eggert, P.R.', '1D']
# ['CS001611A', 'COM SCI', '161', 'Fundamentals of Artificial Intelligence', 'Eggert, P.R.', '1A']
# ['CS001611B', 'COM SCI', '161', 'Fundamentals of Artificial Intelligence', 'Eggert, P.R.', '1B']
# ['CS001611C', 'COM SCI', '161', 'Fundamentals of Artificial Intelligence', 'Eggert, P.R.', '1C']
# ['CS001611D', 'COM SCI', '161', 'Fundamentals of Artificial Intelligence', 'Eggert, P.R.', '1D']
# ['CS001621A', 'COM SCI', '162', 'Natural Language Processing', 'Eggert, P.R.', '1A']
# ['CS001621B', 'COM SCI', '162', 'Natural Language Processing', 'Eggert, P.R.', '1B']
# ['CS001621C', 'COM SCI', '162', 'Natural Language Processing', 'Eggert, P.R.', '1C']
# ['CS001621D', 'COM SCI', '162', 'Natural Language Processing', 'Eggert, P.R.', '1D']
# ['CS001681A', 'COM SCI', '168', 'Computational Methods for Medical Imaging', 'Eggert, P.R.', '1A']
# ['CS001681B', 'COM SCI', '168', 'Computational Methods for Medical Imaging', 'Eggert, P.R.', '1B']
# ['CS001681C', 'COM SCI', '168', 'Computational Methods for Medical Imaging', 'Eggert, P.R.', '1C']
# ['CS001681D', 'COM SCI', '168', 'Computational Methods for Medical Imaging', 'Eggert, P.R.', '1D']
# ['CSM171L1A', 'COM SCI', 'M171L', 'Data Communication Systems Laboratory', 'Eggert, P.R.', '1A']
# ['CSM171L1B', 'COM SCI', 'M171L', 'Data Communication Systems Laboratory', 'Eggert, P.R.', '1B']
# ['CSM171L1C', 'COM SCI', 'M171L', 'Data Communication Systems Laboratory', 'Eggert, P.R.', '1C']
# ['CSM171L1D', 'COM SCI', 'M171L', 'Data Communication Systems Laboratory', 'Eggert, P.R.', '1D']
# ['CS001721A', 'COM SCI', '172', 'Real-Time Three-Dimensional Animation', 'Eggert, P.R.', '1A']
# ['CS001721B', 'COM SCI', '172', 'Real-Time Three-Dimensional Animation', 'Eggert, P.R.', '1B']
# ['CS001721C', 'COM SCI', '172', 'Real-Time Three-Dimensional Animation', 'Eggert, P.R.', '1C']
# ['CS001721D', 'COM SCI', '172', 'Real-Time Three-Dimensional Animation', 'Eggert, P.R.', '1D']
# ['CS0174A1A', 'COM SCI', '174A', 'Introduction to Computer Graphics', 'Eggert, P.R.', '1A']
# ['CS0174A1B', 'COM SCI', '174A', 'Introduction to Computer Graphics', 'Eggert, P.R.', '1B']
# ['CS0174A1C', 'COM SCI', '174A', 'Introduction to Computer Graphics', 'Eggert, P.R.', '1C']
# ['CS0174A1D', 'COM SCI', '174A', 'Introduction to Computer Graphics', 'Eggert, P.R.', '1D']
# ['CSC174C1A', 'COM SCI', 'C174C', 'Computer Animation', 'Eggert, P.R.', '1A']
# ['CSC174C1B', 'COM SCI', 'C174C', 'Computer Animation', 'Eggert, P.R.', '1B']
# ['CSC174C1C', 'COM SCI', 'C174C', 'Computer Animation', 'Eggert, P.R.', '1C']
# ['CSC174C1D', 'COM SCI', 'C174C', 'Computer Animation', 'Eggert, P.R.', '1D']
# ['CS001801A', 'COM SCI', '180', 'Introduction to Algorithms and Complexity', 'Eggert, P.R.', '1A']
# ['CS001801B', 'COM SCI', '180', 'Introduction to Algorithms and Complexity', 'Eggert, P.R.', '1B']
# ['CS001801C', 'COM SCI', '180', 'Introduction to Algorithms and Complexity', 'Eggert, P.R.', '1C']
# ['CS001801D', 'COM SCI', '180', 'Introduction to Algorithms and Complexity', 'Eggert, P.R.', '1D']
# ['CS001811A', 'COM SCI', '181', 'Theory of Computing', 'Eggert, P.R.', '1A']
# ['CS001811B', 'COM SCI', '181', 'Theory of Computing', 'Eggert, P.R.', '1B']
# ['CS001811C', 'COM SCI', '181', 'Theory of Computing', 'Eggert, P.R.', '1C']
# ['CS001811D', 'COM SCI', '181', 'Theory of Computing', 'Eggert, P.R.', '1D']
# ['CS001831A', 'COM SCI', '183', 'Introduction to Cryptography', 'Eggert, P.R.', '1A']
# ['CS001831B', 'COM SCI', '183', 'Introduction to Cryptography', 'Eggert, P.R.', '1B']
# ['CS001831C', 'COM SCI', '183', 'Introduction to Cryptography', 'Eggert, P.R.', '1C']
# ['CS001831D', 'COM SCI', '183', 'Introduction to Cryptography', 'Eggert, P.R.', '1D']
# ['CSCM2861A', 'COM SCI', 'CM286', 'Letter grading', 'Eggert, P.R.', '1A']
# ['CSCM2861B', 'COM SCI', 'CM286', 'Letter grading', 'Eggert, P.R.', '1B']
# ['CSCM2861C', 'COM SCI', 'CM286', 'Letter grading', 'Eggert, P.R.', '1C']
# ...
# ['PS0240B1D', 'POLI SCI', '240B', 'Seminars: Comparative Politics', 'Eggert, P.R.', '1D']
# ['PS002411A', 'POLI SCI', '241', 'African Politics', 'Eggert, P.R.', '1A']
# ['PS002411B', 'POLI SCI', '241', 'African Politics', 'Eggert, P.R.', '1B']
# ['PS002411C', 'POLI SCI', '241', 'African Politics', 'Eggert, P.R.', '1C']
# ['PS002411D', 'POLI SCI', '241', 'African Politics', 'Eggert, P.R.', '1D']
# ['PS002421A', 'POLI SCI', '242', 'Chinese and East Asian Politics', 'Eggert, P.R.', '1A']
# ['PS002421B', 'POLI SCI', '242', 'Chinese and East Asian Politics', 'Eggert, P.R.', '1B']
# ['PS002421C', 'POLI SCI', '242', 'Chinese and East Asian Politics', 'Eggert, P.R.', '1C']
# ['PS002421D', 'POLI SCI', '242', 'Chinese and East Asian Politics', 'Eggert, P.R.', '1D']
# ['PS002431A', 'POLI SCI', '243', 'Japanese and Western Pacific Politics', 'Eggert, P.R.', '1A']
# ['PS002431B', 'POLI SCI', '243', 'Japanese and Western Pacific Politics', 'Eggert, P.R.', '1B']
# ['PS002431C', 'POLI SCI', '243', 'Japanese and Western Pacific Politics', 'Eggert, P.R.', '1C']
# ['PS002431D', 'POLI SCI', '243', 'Japanese and Western Pacific Politics', 'Eggert, P.R.', '1D']
# ['PS002441A', 'POLI SCI', '244', 'Latin American Politics', 'Eggert, P.R.', '1A']
# ['PS002441B', 'POLI SCI', '244', 'Latin American Politics', 'Eggert, P.R.', '1B']
# ['PS002441C', 'POLI SCI', '244', 'Latin American Politics', 'Eggert, P.R.', '1C']
# ['PS002441D', 'POLI SCI', '244', 'Latin American Politics', 'Eggert, P.R.', '1D']
# ['PS002451A', 'POLI SCI', '245', 'Middle Eastern Politics', 'Eggert, P.R.', '1A']
# ['PS002451B', 'POLI SCI', '245', 'Middle Eastern Politics', 'Eggert, P.R.', '1B']
# ['PS002451C', 'POLI SCI', '245', 'Middle Eastern Politics', 'Eggert, P.R.', '1C']
# ['PS002451D', 'POLI SCI', '245', 'Middle Eastern Politics', 'Eggert, P.R.', '1D']
# ['PS0246A1A', 'POLI SCI', '246A', 'Western European Politics', 'Eggert, P.R.', '1A']
# ['PS0246A1B', 'POLI SCI', '246A', 'Western European Politics', 'Eggert, P.R.', '1B']
# ['PS0246A1C', 'POLI SCI', '246A', 'Western European Politics', 'Eggert, P.R.', '1C']
# ['PS0246A1D', 'POLI SCI', '246A', 'Western European Politics', 'Eggert, P.R.', '1D']
# ['PS0246B1A', 'POLI SCI', '246B', 'Political Development of Modern Europe', 'Eggert, P.R.', '1A']
# ['PS0246B1B', 'POLI SCI', '246B', 'Political Development of Modern Europe', 'Eggert, P.R.', '1B']
# ['PS0246B1C', 'POLI SCI', '246B', 'Political Development of Modern Europe', 'Eggert, P.R.', '1C']
# ['PS0246B1D', 'POLI SCI', '246B', 'Political Development of Modern Europe', 'Eggert, P.R.', '1D']
# ['PS0247A1A', 'POLI SCI', '247A', 'Evolution of Soviet and Russian Politics', 'Eggert, P.R.', '1A']
# ['PS0247A1B', 'POLI SCI', '247A', 'Evolution of Soviet and Russian Politics', 'Eggert, P.R.', '1B']
# ['PS0247A1C', 'POLI SCI', '247A', 'Evolution of Soviet and Russian Politics', 'Eggert, P.R.', '1C']
# ['PS0247A1D', 'POLI SCI', '247A', 'Evolution of Soviet and Russian Politics', 'Eggert, P.R.', '1D']
# ['PS0247B1A', 'POLI SCI', '247B', 'Domestic Context of Russian Foreign Policy', 'Eggert, P.R.', '1A']
# ['PS0247B1B', 'POLI SCI', '247B', 'Domestic Context of Russian Foreign Policy', 'Eggert, P.R.', '1B']
# ['PS0247B1C', 'POLI SCI', '247B', 'Domestic Context of Russian Foreign Policy', 'Eggert, P.R.', '1C']
# ['PS0247B1D', 'POLI SCI', '247B', 'Domestic Context of Russian Foreign Policy', 'Eggert, P.R.', '1D']
# ['PS002481A', 'POLI SCI', '248', 'South Asian Politics', 'Eggert, P.R.', '1A']
# ['PS002481B', 'POLI SCI', '248', 'South Asian Politics', 'Eggert, P.R.', '1B']
# ['PS002481C', 'POLI SCI', '248', 'South Asian Politics', 'Eggert, P.R.', '1C']
# ['PS002481D', 'POLI SCI', '248', 'South Asian Politics', 'Eggert, P.R.', '1D']
# ['PS002511A', 'POLI SCI', '251', 'Political Economy of Economic Reform', 'Eggert, P.R.', '1A']
# ['PS002511B', 'POLI SCI', '251', 'Political Economy of Economic Reform', 'Eggert, P.R.', '1B']
# ['PS002511C', 'POLI SCI', '251', 'Political Economy of Economic Reform', 'Eggert, P.R.', '1C']
# ['PS002511D', 'POLI SCI', '251', 'Political Economy of Economic Reform', 'Eggert, P.R.', '1D']
# ['PS002521A', 'POLI SCI', '252', 'Parties and Party Systems', 'Eggert, P.R.', '1A']
# ['PS002521B', 'POLI SCI', '252', 'Parties and Party Systems', 'Eggert, P.R.', '1B']
# ['PS002521C', 'POLI SCI', '252', 'Parties and Party Systems', 'Eggert, P.R.', '1C']
# ['PS002521D', 'POLI SCI', '252', 'Parties and Party Systems', 'Eggert, P.R.', '1D']
# ['PS002531A', 'POLI SCI', '253', 'Political Change in Communist Systems', 'Eggert, P.R.', '1A']
# ['PS002531B', 'POLI SCI', '253', 'Political Change in Communist Systems', 'Eggert, P.R.', '1B']
# ['PS002531C', 'POLI SCI', '253', 'Political Change in Communist Systems', 'Eggert, P.R.', '1C']
# ['PS002531D', 'POLI SCI', '253', 'Political Change in Communist Systems', 'Eggert, P.R.', '1D']
# ['PS002561A', 'POLI SCI', '256', 'External Sources of Domestic Politics', 'Eggert, P.R.', '1A']
# ['PS002561B', 'POLI SCI', '256', 'External Sources of Domestic Politics', 'Eggert, P.R.', '1B']
# ['PS002561C', 'POLI SCI', '256', 'External Sources of Domestic Politics', 'Eggert, P.R.', '1C']
# ['PS002561D', 'POLI SCI', '256', 'External Sources of Domestic Politics', 'Eggert, P.R.', '1D']
# ['PS002571A', 'POLI SCI', '257', 'Labor and Working-Class Politics', 'Eggert, P.R.', '1A']
# ['PS002571B', 'POLI SCI', '257', 'Labor and Working-Class Politics', 'Eggert, P.R.', '1B']
# ['PS002571C', 'POLI SCI', '257', 'Labor and Working-Class Politics', 'Eggert, P.R.', '1C']
# ['PS002571D', 'POLI SCI', '257', 'Labor and Working-Class Politics', 'Eggert, P.R.', '1D']
# ['PS002581A', 'POLI SCI', '258', 'Comparative Politics Proseminar', 'Eggert, P.R.', '1A']
# ['PS002581B', 'POLI SCI', '258', 'Comparative Politics Proseminar', 'Eggert, P.R.', '1B']
# ['PS002581C', 'POLI SCI', '258', 'Comparative Politics Proseminar', 'Eggert, P.R.', '1C']
# ['PS002581D', 'POLI SCI', '258', 'Comparative Politics Proseminar', 'Eggert, P.R.', '1D']
# ['PS002591A', 'POLI SCI', '259', 'Selected Topics in Comparative Politics', 'Eggert, P.R.', '1A']
# ['PS002591B', 'POLI SCI', '259', 'Selected Topics in Comparative Politics', 'Eggert, P.R.', '1B']
# ['PS002591C', 'POLI SCI', '259', 'Selected Topics in Comparative Politics', 'Eggert, P.R.', '1C']
# ['PS002591D', 'POLI SCI', '259', 'Selected Topics in Comparative Politics', 'Eggert, P.R.', '1D']
# ['PSM261A1A', 'POLI SCI', 'M261A', 'Proseminar: Political Psychology', 'Eggert, P.R.', '1A']
# ['PSM261A1B', 'POLI SCI', 'M261A', 'Proseminar: Political Psychology', 'Eggert, P.R.', '1B']
# ['PSM261A1C', 'POLI SCI', 'M261A', 'Proseminar: Political Psychology', 'Eggert, P.R.', '1C']
# ['PSM261A1D', 'POLI SCI', 'M261A', 'Proseminar: Political Psychology', 'Eggert, P.R.', '1D']
# ['PS0261B1A', 'POLI SCI', '261B', 'Mass Attitudes and Political Behavior', 'Eggert, P.R.', '1A']
# ['PS0261B1B', 'POLI SCI', '261B', 'Mass Attitudes and Political Behavior', 'Eggert, P.R.', '1B']
# ['PS0261B1C', 'POLI SCI', '261B', 'Mass Attitudes and Political Behavior', 'Eggert, P.R.', '1C']
# ['PS0261B1D', 'POLI SCI', '261B', 'Mass Attitudes and Political Behavior', 'Eggert, P.R.', '1D']
# ['PS0261C1A', 'POLI SCI', '261C', 'Political Communication', 'Eggert, P.R.', '1A']
# ['PS0261C1B', 'POLI SCI', '261C', 'Political Communication', 'Eggert, P.R.', '1B']
# ['PS0261C1C', 'POLI SCI', '261C', 'Political Communication', 'Eggert, P.R.', '1C']
# ['PS0261C1D', 'POLI SCI', '261C', 'Political Communication', 'Eggert, P.R.', '1D']
# ['PSM261D1A', 'POLI SCI', 'M261D', 'Seminar: Political Psychology', 'Eggert, P.R.', '1A']
# ['PSM261D1B', 'POLI SCI', 'M261D', 'Seminar: Political Psychology', 'Eggert, P.R.', '1B']
# ['PSM261D1C', 'POLI SCI', 'M261D', 'Seminar: Political Psychology', 'Eggert, P.R.', '1C']
# ['PSM261D1D', 'POLI SCI', 'M261D', 'Seminar: Political Psychology', 'Eggert, P.R.', '1D']
# ['PSM261E1A', 'POLI SCI', 'M261E', 'Critical Problems in Political Psychology', 'Eggert, P.R.', '1A']
# ['PSM261E1B', 'POLI SCI', 'M261E', 'Critical Problems in Political Psychology', 'Eggert, P.R.', '1B']
# ['PSM261E1C', 'POLI SCI', 'M261E', 'Critical Problems in Political Psychology', 'Eggert, P.R.', '1C']
# ['PSM261E1D', 'POLI SCI', 'M261E', 'Critical Problems in Political Psychology', 'Eggert, P.R.', '1D']
# ['PS002621A', 'POLI SCI', '262', 'Political Parties', 'Eggert, P.R.', '1A']
# ['PS002621B', 'POLI SCI', '262', 'Political Parties', 'Eggert, P.R.', '1B']
# ['PS002621C', 'POLI SCI', '262', 'Political Parties', 'Eggert, P.R.', '1C']
# ['PS002621D', 'POLI SCI', '262', 'Political Parties', 'Eggert, P.R.', '1D']
# ['PS002641A', 'POLI SCI', '264', 'Politics and Society', 'Eggert, P.R.', '1A']
# ['PS002641B', 'POLI SCI', '264', 'Politics and Society', 'Eggert, P.R.', '1B']
# ['PS002641C', 'POLI SCI', '264', 'Politics and Society', 'Eggert, P.R.', '1C']
# ['PS002641D', 'POLI SCI', '264', 'Politics and Society', 'Eggert, P.R.', '1D']
# ['PS002651A', 'POLI SCI', '265', 'Politics and Economy', 'Eggert, P.R.', '1A']
# ['PS002651B', 'POLI SCI', '265', 'Politics and Economy', 'Eggert, P.R.', '1B']
# ['PS002651C', 'POLI SCI', '265', 'Politics and Economy', 'Eggert, P.R.', '1C']
# ['PS002651D', 'POLI SCI', '265', 'Politics and Economy', 'Eggert, P.R.', '1D']
# ['PS002661A', 'POLI SCI', '266', 'Group Theories of Politics', 'Eggert, P.R.', '1A']
# ['PS002661B', 'POLI SCI', '266', 'Group Theories of Politics', 'Eggert, P.R.', '1B']
# ['PS002661C', 'POLI SCI', '266', 'Group Theories of Politics', 'Eggert, P.R.', '1C']
# ['PS002661D', 'POLI SCI', '266', 'Group Theories of Politics', 'Eggert, P.R.', '1D']
# ['PS002681A', 'POLI SCI', '268', 'Seminar: Political and Electoral Problems', 'Eggert, P.R.', '1A']
# ['PS002681B', 'POLI SCI', '268', 'Seminar: Political and Electoral Problems', 'Eggert, P.R.', '1B']
# ['PS002681C', 'POLI SCI', '268', 'Seminar: Political and Electoral Problems', 'Eggert, P.R.', '1C']
# ['PS002681D', 'POLI SCI', '268', 'Seminar: Political and Electoral Problems', 'Eggert, P.R.', '1D']
# ['PS002691A', 'POLI SCI', '269', 'Seminar: Political Behavior', 'Eggert, P.R.', '1A']
# ['PS002691B', 'POLI SCI', '269', 'Seminar: Political Behavior', 'Eggert, P.R.', '1B']
# ['PS002691C', 'POLI SCI', '269', 'Seminar: Political Behavior', 'Eggert, P.R.', '1C']
# ['PS002691D', 'POLI SCI', '269', 'Seminar: Political Behavior', 'Eggert, P.R.', '1D']
# ['PS002701A', 'POLI SCI', '270', 'Legislative Behavior', 'Eggert, P.R.', '1A']
# ['PS002701B', 'POLI SCI', '270', 'Legislative Behavior', 'Eggert, P.R.', '1B']
# ['PS002701C', 'POLI SCI', '270', 'Legislative Behavior', 'Eggert, P.R.', '1C']
# ['PS002701D', 'POLI SCI', '270', 'Legislative Behavior', 'Eggert, P.R.', '1D']
# ['PS002711A', 'POLI SCI', '271', 'Executive Politics and Presidency', 'Eggert, P.R.', '1A']
# ['PS002711B', 'POLI SCI', '271', 'Executive Politics and Presidency', 'Eggert, P.R.', '1B']
# ['PS002711C', 'POLI SCI', '271', 'Executive Politics and Presidency', 'Eggert, P.R.', '1C']
# ['PS002711D', 'POLI SCI', '271', 'Executive Politics and Presidency', 'Eggert, P.R.', '1D']
# ['PS002721A', 'POLI SCI', '272', 'Political Environment of Federal Executive', 'Eggert, P.R.', '1A']
# ['PS002721B', 'POLI SCI', '272', 'Political Environment of Federal Executive', 'Eggert, P.R.', '1B']
# ['PS002721C', 'POLI SCI', '272', 'Political Environment of Federal Executive', 'Eggert, P.R.', '1C']
# ['PS002721D', 'POLI SCI', '272', 'Political Environment of Federal Executive', 'Eggert, P.R.', '1D']
# ['PS002731A', 'POLI SCI', '273', 'American Political Development', 'Eggert, P.R.', '1A']
# ['PS002731B', 'POLI SCI', '273', 'American Political Development', 'Eggert, P.R.', '1B']
# ['PS002731C', 'POLI SCI', '273', 'American Political Development', 'Eggert, P.R.', '1C']
# ['PS002731D', 'POLI SCI', '273', 'American Political Development', 'Eggert, P.R.', '1D']
# ['PS002751A', 'POLI SCI', '275', 'Seminar: American Political Institutions', 'Eggert, P.R.', '1A']
# ['PS002751B', 'POLI SCI', '275', 'Seminar: American Political Institutions', 'Eggert, P.R.', '1B']
# ['PS002751C', 'POLI SCI', '275', 'Seminar: American Political Institutions', 'Eggert, P.R.', '1C']
# ['PS002751D', 'POLI SCI', '275', 'Seminar: American Political Institutions', 'Eggert, P.R.', '1D']
# ['PS0280A1A', 'POLI SCI', '280A', 'Race and Ethnic Politics Field Seminar 1', 'Eggert, P.R.', '1A']
# ['PS0280A1B', 'POLI SCI', '280A', 'Race and Ethnic Politics Field Seminar 1', 'Eggert, P.R.', '1B']
# ['PS0280A1C', 'POLI SCI', '280A', 'Race and Ethnic Politics Field Seminar 1', 'Eggert, P.R.', '1C']
# ['PS0280A1D', 'POLI SCI', '280A', 'Race and Ethnic Politics Field Seminar 1', 'Eggert, P.R.', '1D']
# ['PS0280B1A', 'POLI SCI', '280B', 'Research Methods in Race-Ethnicity Politics', 'Eggert, P.R.', '1A']
# ['PS0280B1B', 'POLI SCI', '280B', 'Research Methods in Race-Ethnicity Politics', 'Eggert, P.R.', '1B']
# ['PS0280B1C', 'POLI SCI', '280B', 'Research Methods in Race-Ethnicity Politics', 'Eggert, P.R.', '1C']
# ['PS0280B1D', 'POLI SCI', '280B', 'Research Methods in Race-Ethnicity Politics', 'Eggert, P.R.', '1D']
# ['PS002901A', 'POLI SCI', '290', 'Modern Political Economy', 'Eggert, P.R.', '1A']
# ['PS002901B', 'POLI SCI', '290', 'Modern Political Economy', 'Eggert, P.R.', '1B']
# ['PS002901C', 'POLI SCI', '290', 'Modern Political Economy', 'Eggert, P.R.', '1C']
# ['PS002901D', 'POLI SCI', '290', 'Modern Political Economy', 'Eggert, P.R.', '1D']
# ['PS002931A', 'POLI SCI', '293', 'Great Ideas in Social Sciences', 'Eggert, P.R.', '1A']
# ['PS002931B', 'POLI SCI', '293', 'Great Ideas in Social Sciences', 'Eggert, P.R.', '1B']
# ['PS002931C', 'POLI SCI', '293', 'Great Ideas in Social Sciences', 'Eggert, P.R.', '1C']
# ['PS002931D', 'POLI SCI', '293', 'Great Ideas in Social Sciences', 'Eggert, P.R.', '1D']
# ['PS003751A', 'POLI SCI', '375', 'Teaching Apprentice Practicum', 'Eggert, P.R.', '1A']
# ['PS003751B', 'POLI SCI', '375', 'Teaching Apprentice Practicum', 'Eggert, P.R.', '1B']
# ['PS003751C', 'POLI SCI', '375', 'Teaching Apprentice Practicum', 'Eggert, P.R.', '1C']
# ['PS003751D', 'POLI SCI', '375', 'Teaching Apprentice Practicum', 'Eggert, P.R.', '1D']
# ['PS004951A', 'POLI SCI', '495', 'Teaching Political Science', 'Eggert, P.R.', '1A']
# ['PS004951B', 'POLI SCI', '495', 'Teaching Political Science', 'Eggert, P.R.', '1B']
# ['PS004951C', 'POLI SCI', '495', 'Teaching Political Science', 'Eggert, P.R.', '1C']
# ['PS004951D', 'POLI SCI', '495', 'Teaching Political Science', 'Eggert, P.R.', '1D']
# ['PS0495A1A', 'POLI SCI', '495A', 'Teaching Political Science 1', 'Eggert, P.R.', '1A']
# ['PS0495A1B', 'POLI SCI', '495A', 'Teaching Political Science 1', 'Eggert, P.R.', '1B']
# ['PS0495A1C', 'POLI SCI', '495A', 'Teaching Political Science 1', 'Eggert, P.R.', '1C']
# ['PS0495A1D', 'POLI SCI', '495A', 'Teaching Political Science 1', 'Eggert, P.R.', '1D']
# ['PS0495B1A', 'POLI SCI', '495B', 'Teaching Political Science 2', 'Eggert, P.R.', '1A']
# ['PS0495B1B', 'POLI SCI', '495B', 'Teaching Political Science 2', 'Eggert, P.R.', '1B']
# ['PS0495B1C', 'POLI SCI', '495B', 'Teaching Political Science 2', 'Eggert, P.R.', '1C']
# ['PS0495B1D', 'POLI SCI', '495B', 'Teaching Political Science 2', 'Eggert, P.R.', '1D']
# ['PS005011A', 'POLI SCI', '501', 'Cooperative Program', 'Eggert, P.R.', '1A']
# ['PS005011B', 'POLI SCI', '501', 'Cooperative Program', 'Eggert, P.R.', '1B']
# ['PS005011C', 'POLI SCI', '501', 'Cooperative Program', 'Eggert, P.R.', '1C']
# ['PS005011D', 'POLI SCI', '501', 'Cooperative Program', 'Eggert, P.R.', '1D']
# ['PS005961A', 'POLI SCI', '596', 'Directed Individual Study or Research', 'Eggert, P.R.', '1A']
# ['PS005961B', 'POLI SCI', '596', 'Directed Individual Study or Research', 'Eggert, P.R.', '1B']
# ['PS005961C', 'POLI SCI', '596', 'Directed Individual Study or Research', 'Eggert, P.R.', '1C']
# ['PS005961D', 'POLI SCI', '596', 'Directed Individual Study or Research', 'Eggert, P.R.', '1D']
# ['PS005971A', 'POLI SCI', '597', 'Preparation for PhD Qualifying Examinations', 'Eggert, P.R.', '1A']
# ['PS005971B', 'POLI SCI', '597', 'Preparation for PhD Qualifying Examinations', 'Eggert, P.R.', '1B']
# ['PS005971C', 'POLI SCI', '597', 'Preparation for PhD Qualifying Examinations', 'Eggert, P.R.', '1C']
# ['PS005971D', 'POLI SCI', '597', 'Preparation for PhD Qualifying Examinations', 'Eggert, P.R.', '1D']

# %%
#defining only the sections we need to get the names of the majors
major_text = extract_text_from_pdf('/Users/dayfamily/Desktop/UCLA_Catalog_2023-24.pdf', start_page=8, end_page=15)

# %%
major_testing = extract_text_from_pdf('/Users/dayfamily/Desktop/UCLA_Catalog_2023-24.pdf', start_page=185, end_page=200)

# %%
#a regular expression that looks for a specific pattern that matches how the pdf stores info about majors; not completely perfect
major_pattern = r'(.+?)\s*(?:\nCollege of Letters and Science|$)'

major_matches = re.findall(major_pattern, major_testing, re.DOTALL)

print(major_matches)
